# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install -q -U google-generativeai pillow pdf2image opencv-python # Añadido opencv-python
# !apt-get install -y poppler-utils # Necesario para pdf2image
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# poppler-utils is already the newest version (22.02.0-2ubuntu0.8).
# 0 upgraded, 0 newly installed, 0 to remove and 35 not upgraded.

# %%
import google.generativeai as genai
from PIL import Image
import os
from pdf2image import convert_from_path
import json

# --- Configuración de la API Key ---
from google.colab import userdata

try:
    GOOGLE_API_KEY = userdata.get('GOOGLE_API_KEY')
    genai.configure(api_key=GOOGLE_API_KEY)
    print("API Key cargada y configurada exitosamente.")
except userdata.SecretNotFoundError:
    print("Error: El secreto 'GOOGLE_API_KEY' no fue encontrado.")
    print("Por favor, añade tu API Key a los secretos de Colab.")
    GOOGLE_API_KEY = None # Asegurarse de que GOOGLE_API_KEY es None si no se encuentra
except Exception as e:
    print(f"Ocurrió un error al configurar la API Key: {e}")
    GOOGLE_API_KEY = None # Asegurarse de que GOOGLE_API_KEY es None si hay error

# --- Configuración del Modelo ---
# (Asegúrate de que GOOGLE_API_KEY se haya cargado correctamente antes de esto)
if GOOGLE_API_KEY:
    model_name = 'gemini-1.5-flash-latest' # o 'gemini-1.5-pro-latest'
    model = genai.GenerativeModel(model_name)
    print(f"Modelo {model_name} inicializado.")
else:
    model = None
    print("El modelo no se pudo inicializar porque la API Key no está configurada.")
# Out:
# API Key cargada y configurada exitosamente.
# Modelo gemini-1.5-flash-latest inicializado.

# %%
# import os
# import shutil

# # Crear directorios si no existen
# IMAGES_DIR = "pdf_images"
# if os.path.exists(IMAGES_DIR):
#     shutil.rmtree(IMAGES_DIR)
# os.makedirs(IMAGES_DIR, exist_ok=True)

# pdf_path = '/content/drive/MyDrive/DEUDA_PREVISIONAL/PDFS/2017.pdf' # Asegúrate que esta ruta sea correcta

# if not os.path.exists(pdf_path):
#     print(f"Error: No se encontró el archivo PDF en la ruta especificada: {pdf_path}")
#     image_paths = []
# else:
#     print(f"Archivo '{pdf_path}' encontrado.")

#     try:
#         print("Convirtiendo PDF a imágenes...")
#         from pdf2image import convert_from_path
#         images = convert_from_path(pdf_path, dpi=300)
#         image_paths = []
#         for i, image in enumerate(images):
#             image_path = os.path.join(IMAGES_DIR, f"page_{i+1}.png")
#             image.save(image_path, "PNG")
#             image_paths.append(image_path)
#             print(f"Página {i+1} guardada como {image_path}")
#         print(f"Conversión completa. {len(image_paths)} imágenes generadas en la carpeta '{IMAGES_DIR}'.")
#     except Exception as e:
#         print(f"Error al convertir el PDF a imágenes: {e}")
#         image_paths = []

# %%
# Especifica la ruta de la carpeta en Google Drive que contiene las imágenes
drive_image_folder_path = '/content/drive/MyDrive/DEUDA_PREVISIONAL/PDFS/2017'

# Verifica si la carpeta existe
if not os.path.exists(drive_image_folder_path):
    print(f"Error: No se encontró la carpeta de imágenes en la ruta especificada: {drive_image_folder_path}")
    image_paths = []
else:
    print(f"Carpeta '{drive_image_folder_path}' encontrada.")

    # Lista todos los archivos dentro de la carpeta y filtra solo los archivos de imagen (puedes ajustar las extensiones)
    all_files_in_folder = os.listdir(drive_image_folder_path)
    image_extensions = ('.png') # Define las extensiones de imagen que te interesan
    image_paths = [os.path.join(drive_image_folder_path, filename)
                   for filename in all_files_in_folder
                   if filename.lower().endswith(image_extensions) and os.path.isfile(os.path.join(drive_image_folder_path, filename))]

    if not image_paths:
        print("No se encontraron archivos de imagen en la carpeta especificada.")
    else:
        print(f"Se encontraron {len(image_paths)} archivos de imagen en la carpeta.")
# Out:
# Carpeta '/content/drive/MyDrive/DEUDA_PREVISIONAL/PDFS/2017' encontrada.
# Se encontraron 31 archivos de imagen en la carpeta.

# %%
# CELDA QUE CONTIENE extract_data_from_image_gemini_v_few_shot (MODIFICADA PARA PREPROCESAMIENTO)
import google.generativeai as genai
from PIL import Image
import json
import os

# (Asegúrate de que 'model' esté definido globalmente o se pase como argumento)

def extract_data_from_image_gemini_v_few_shot_pil(pil_image_obj, target_dia_pago="31.12.2017", image_identifier="PIL_Image_Object"):
    if 'model' not in globals() or globals()['model'] is None:
        print("Error: La variable global 'model' de Gemini no está inicializada.")
        print("Asegúrate de haber configurado la API Key y el modelo en una celda anterior.")
        return None

    if not isinstance(pil_image_obj, Image.Image):
        print(f"Error: El objeto proporcionado no es una imagen PIL.Image válida para {image_identifier}")
        return None

    img_to_send = pil_image_obj

    prompt = f"""
    Analiza la siguiente imagen, que contiene tablas de datos financieros. Tu tarea es extraer información específica de la fila donde "DIA DE PAGO" es "{target_dia_pago}".

    La imagen presenta datos financieros organizados en columnas, donde cada columna principal representa un mes y año (ej. "MAYO 1997", "JUNIO 1997", etc.). Debes procesar estas columnas de mes/año de izquierda a derecha como las encuentres en la imagen.

    Para cada columna de mes/año que identifiques:
    1.  **mes_año_columna**: Extrae el nombre completo del mes y año que encabeza esta columna.
    2.  **reajuste_porcentaje**: Busca el valor de "REAJUSTE %" que está visualmente asociado y típicamente ubicado encima de la columna del mes/año actual. Extrae solo el valor porcentual, omitiendo la palabra "REAJUSTE" si está presente.
    3.  Localiza la fila de datos correspondiente a "{target_dia_pago}".
    4.  Dentro de esta fila "{target_dia_pago}" y asegurándote de que estás obteniendo los valores de la columna del mes/año actual que estás procesando:
        a.  **interes_afiliado_porcentaje**: Busca la sección principal de "INTERES" (usualmente "% INTERES"). Debajo de este encabezado, para el mes/año actual, extrae el valor de la primera columna de datos numéricos.
        b.  **recargo_beneficio_afiliado_porcentaje**: Busca la sección principal de "RECARGO BENEFICIO" (ej. "* RECARGO BENEFICIO %" o "% RECARGO BENEFICIO"). Esta sección tiene subcolumnas "AFILIADO" y "A.F.P.". Para el mes/año actual, extrae el valor específicamente de la subcolumna "AFILIADO". Ignora la subcolumna "A.F.P.". Si la celda "AFILIADO" bajo "RECARGO BENEFICIO" para el mes/año actual y la fecha objetivo está vacía o no es un valor numérico claro, asígnalo como null.

    **Es muy importante que intentes encontrar y extraer un valor para los tres campos (reajuste_porcentaje, interes_afiliado_porcentaje, recargo_beneficio_afiliado_porcentaje) para cada mes_año_columna que identifiques y que contenga datos en la fila objetivo. Asigna null solo si el valor está genuinamente ausente o es ilegible. No omitas campos si los datos correspondientes existen.**

    Presenta los resultados como una lista de objetos JSON, manteniendo el orden de izquierda a derecha en que aparecen los meses/años en la imagen. Cada objeto debe tener las claves: "mes_año_columna", "reajuste_porcentaje", "interes_afiliado_porcentaje", "recargo_beneficio_afiliado_porcentaje".

    Si para un mes/año particular no encuentras la fila "{target_dia_pago}" o los datos requeridos de forma clara, omite ese mes/año de la lista. Si no encuentras datos válidos para ningún mes/año en la imagen, devuelve una lista vacía.

    Aquí tienes ejemplos de la extracción correcta para la fila "{target_dia_pago}":
    Ejemplo 1:
    {{
      "mes_año_columna": "MAYO 1997",
      "reajuste_porcentaje": "13.70%",
      "interes_afiliado_porcentaje": "3293.80%",
      "recargo_beneficio_afiliado_porcentaje": "658.76%"
    }}
    Ejemplo 2:
    {{
      "mes_año_columna": "JUNIO 1997",
      "reajuste_porcentaje": "13.70%",
      "interes_afiliado_porcentaje": "3250.14%",
      "recargo_beneficio_afiliado_porcentaje": "650.03%"
    }}
    Ejemplo 3:
    {{
      "mes_año_columna": "JULIO 1997",
      "reajuste_porcentaje": "13.70%",
      "interes_afiliado_porcentaje": "3207.96%",
      "recargo_beneficio_afiliado_porcentaje": "641.59%"
    }}
    Ejemplo 4:
    {{
      "mes_año_columna": "AGOSTO 1997",
      "reajuste_porcentaje": "13.48%",
      "interes_afiliado_porcentaje": "3171.31%",
      "recargo_beneficio_afiliado_porcentaje": "634.38%"
    }}
    Ejemplo 5:
    {{
      "mes_año_columna": "SEPTIEMBRE 1997",
      "reajuste_porcentaje": "13.01%",
      "interes_afiliado_porcentaje": "3143.02%",
      "recargo_beneficio_afiliado_porcentaje": "628.60%"
    }}
    """
    print(f"\nProcesando imagen: {image_identifier} con Gemini, prompt v_few_shot (con énfasis anti-omisión)...")
    try:
        global_model = globals()['model']
        response = global_model.generate_content([prompt, img_to_send], stream=False)
        response.resolve()

        text_response = response.text
        print(f"Respuesta cruda de Gemini para {image_identifier}:\n{text_response}")

        json_str = text_response
        if "```json" in text_response:
            try:
                json_str = text_response.split("```json")[1].split("```")[0].strip()
            except IndexError:
                print(f"Advertencia: Se encontró '```json' pero no se pudo parsear el bloque para {image_identifier}.")
                json_str = text_response
        elif text_response.strip().startswith("```") and text_response.strip().endswith("```"):
            json_str = text_response.strip()[3:-3].strip()
        elif text_response.strip().startswith("[") and text_response.strip().endswith("]"):
             json_str = text_response.strip()
        else:
            print(f"Advertencia: La respuesta de Gemini para {image_identifier} no parece ser un bloque JSON estándar. Se intentará parsear directamente.")

        try:
            extracted_json = json.loads(json_str)
            return extracted_json
        except json.JSONDecodeError as e:
            print(f"Error al decodificar JSON de la respuesta de Gemini para {image_identifier}: {e}")
            print(f"String que causó el error (json_str):\n>>>\n{json_str}\n<<<")
            print(f"Respuesta original completa (text_response):\n>>>\n{text_response}\n<<<")
            return None

    except Exception as e:
        print(f"Error durante la llamada a la API de Gemini para {image_identifier}: {e}")
        if hasattr(e, 'message'): # Para errores de la API de Google
            print(f"Detalle del error de API: {e.message}")
        elif hasattr(e, 'response') and hasattr(e.response, 'text'): # Para errores de requests (si usaras OpenRouter)
            print(f"Detalle del error de API (respuesta): {e.response.text}")
        return None

def extract_data_from_image_gemini_v_few_shot(image_path, target_dia_pago="31.12.2017"):
    try:
        img_pil = Image.open(image_path)
        return extract_data_from_image_gemini_v_few_shot_pil(img_pil, target_dia_pago, image_identifier=image_path)
    except FileNotFoundError:
        print(f"Error: No se encontró la imagen en la ruta {image_path}")
        return None
    except Exception as e:
        print(f"Error al abrir la imagen {image_path}: {e}")
        return None

# %%
import os
from PIL import Image
import cv2 # <--- NUEVA IMPORTACIÓN
import numpy as np # <--- NUEVA IMPORTACIÓN

# Modifica la definición de la función para incluir los flags de preprocesamiento
def segmentar_y_procesar_pagina_v2(imagen_path_original, num_segmentos_verticales_por_tabla=2, overlap_px=50, aplicar_preprocesamiento=True,
                                   aplicar_upscaling=False, factor_upscaling=1.5,
                                   aplicar_escala_grises=True,
                                   aplicar_clahe=True, clip_limit_clahe=2.0, tile_grid_clahe=(8,8),
                                   aplicar_thresholding_adaptativo=True, block_size_thresh=15, c_value_thresh=5,
                                   aplicar_denoising_mediano=True, kernel_size_denoising=3,
                                   aplicar_nitidez=False):
    """
    Segmenta una imagen de página y procesa cada segmento.
    Incluye opciones para aplicar o no diferentes pasos de preprocesamiento.
    """
    try:
        img_original_pil = Image.open(imagen_path_original) # Abrir con PIL para obtener dimensiones
        ancho_total, altura_total = img_original_pil.size
    except Exception as e:
        print(f"Error abriendo la imagen original {imagen_path_original}: {e}")
        return []

    todos_los_datos_extraidos_pagina = []
    segmento_idx_global = 0

    # --- Estimaciones y Parámetros ---
    y_corte_horizontal_ratio = 0.49
    y_corte_horizontal = int(altura_total * y_corte_horizontal_ratio)

    secciones_tabla_y_coords = [
        (0, y_corte_horizontal),
        (y_corte_horizontal, altura_total)
    ]

    if y_corte_horizontal < int(altura_total * 0.2) or y_corte_horizontal > int(altura_total * 0.8):
        print(f"Página {os.path.basename(imagen_path_original)} parece tener una sola tabla principal o un corte no estándar. Procesando como una sola sección vertical.")
        secciones_tabla_y_coords = [(0, altura_total)]

    # Crear directorio para segmentos guardados si no existe
    segmentos_dir = "segmentos_guardados"
    if not os.path.exists(segmentos_dir):
        os.makedirs(segmentos_dir)
    nombre_base_original = os.path.splitext(os.path.basename(imagen_path_original))[0]

    for i, (y_start, y_end) in enumerate(secciones_tabla_y_coords):
        if y_end - y_start < 100:
            continue

        print(f"\nProcesando sección de tabla horizontal {i+1} (Y: {y_start}-{y_end}) de {os.path.basename(imagen_path_original)}")
        ancho_segmento_base = ancho_total // num_segmentos_verticales_por_tabla

        for j in range(num_segmentos_verticales_por_tabla):
            segmento_idx_global += 1
            x_segmento_start = j * ancho_segmento_base
            x_segmento_end = (j + 1) * ancho_segmento_base

            if j > 0: x_segmento_start -= overlap_px
            if j < num_segmentos_verticales_por_tabla - 1: x_segmento_end += overlap_px

            x_segmento_start = max(0, x_segmento_start)
            x_segmento_end = min(ancho_total, x_segmento_end)

            if x_segmento_start >= x_segmento_end:
                print(f"      Segmento {segmento_idx_global} inválido por superposición excesiva o tabla estrecha. Saltando.")
                continue

            print(f"    Procesando segmento vertical {j+1} de la sección {i+1} (Global ID: {segmento_idx_global}): X[{x_segmento_start}-{x_segmento_end}], Y[{y_start}-{y_end}]")

            segmento_pil = img_original_pil.crop((x_segmento_start, y_start, x_segmento_end, y_end))
            path_segmento_guardado = os.path.join(segmentos_dir, f"{nombre_base_original}_tabla{i+1}_seg{j+1}_orig.png")
            try:
                segmento_pil.save(path_segmento_guardado)
                print(f"      Segmento original guardado en: {path_segmento_guardado}")
            except Exception as e_save:
                print(f"      Error al guardar segmento original {path_segmento_guardado}: {e_save}")
                continue

            imagen_a_procesar_pil = segmento_pil
            identificador_imagen = path_segmento_guardado

            if aplicar_preprocesamiento:
                print(f"      Aplicando preprocesamiento al segmento...")
                try:
                    segmento_cv = cv2.cvtColor(np.array(segmento_pil), cv2.COLOR_RGB2BGR)
                    img_procesada_cv = segmento_cv.copy()

                    # --- INICIO CADENA DE PREPROCESAMIENTO (CONTROLADA POR FLAGS) ---
                    if aplicar_upscaling and (img_procesada_cv.shape[0] < 600 or img_procesada_cv.shape[1] < 800): # Condición de ejemplo
                        print(f"        - Aplicando upscaling (factor: {factor_upscaling})")
                        img_procesada_cv = cv2.resize(img_procesada_cv, None, fx=factor_upscaling, fy=factor_upscaling, interpolation=cv2.INTER_LANCZOS4)

                    if aplicar_escala_grises:
                        print("        - Convirtiendo a escala de grises")
                        img_procesada_cv = cv2.cvtColor(img_procesada_cv, cv2.COLOR_BGR2GRAY)
                        img_gray = img_procesada_cv # Mantener una referencia si se necesita

                        if aplicar_clahe:
                            print(f"        - Aplicando CLAHE (clipLimit={clip_limit_clahe}, tileGrid={tile_grid_clahe})")
                            clahe = cv2.createCLAHE(clipLimit=clip_limit_clahe, tileGridSize=tile_grid_clahe)
                            img_procesada_cv = clahe.apply(img_procesada_cv)

                        if aplicar_thresholding_adaptativo:
                             print(f"        - Aplicando thresholding adaptativo (blockSize={block_size_thresh}, C={c_value_thresh})")
                             img_procesada_cv = cv2.adaptiveThreshold(img_procesada_cv, 255, cv2.ADAPTIVE_THRESH_GAUSSIAN_C,
                                                                     cv2.THRESH_BINARY_INV, block_size_thresh, c_value_thresh) # Probando THRESH_BINARY_INV


                        if aplicar_denoising_mediano:
                            # Asegúrate de que kernel_size_denoising sea impar y > 1
                            if kernel_size_denoising % 2 == 0 or kernel_size_denoising <= 1:
                                print(f"        - Advertencia: kernel_size_denoising ({kernel_size_denoising}) debe ser impar y > 1. Usando 3.")
                                kernel_size_denoising = 3
                            print(f"        - Aplicando filtro mediano para eliminación de ruido (kernel={kernel_size_denoising})")
                            img_procesada_cv = cv2.medianBlur(img_procesada_cv, kernel_size_denoising)

                    if aplicar_nitidez:
                        print("        - Aplicando filtro de nitidez")
                        kernel_sharpen = np.array([[-1,-1,-1], [-1,9,-1], [-1,-1,-1]])
                        img_procesada_cv = cv2.filter2D(img_procesada_cv, -1, kernel_sharpen)
                    # --- FIN CADENA DE PREPROCESAMIENTO ---

                    path_segmento_preproc = os.path.join(segmentos_dir, f"{nombre_base_original}_tabla{i+1}_seg{j+1}_preproc.png")
                    cv2.imwrite(path_segmento_preproc, img_procesada_cv)
                    print(f"      Segmento preprocesado guardado en: {path_segmento_preproc}")

                    # Convertir de nuevo a PIL Image para pasarlo a la función de extracción
                    # Detectar si la imagen es en escala de grises o color
                    if len(img_procesada_cv.shape) == 2 or img_procesada_cv.shape[2] == 1:
                        imagen_a_procesar_pil = Image.fromarray(img_procesada_cv, mode='L') # Escala de grises
                    else:
                         imagen_a_procesar_pil = Image.fromarray(cv2.cvtColor(img_procesada_cv, cv2.COLOR_BGR2RGB)) # Color

                    identificador_imagen = path_segmento_preproc

                except ImportError:
                    print("      OpenCV no está instalado. Saltando preprocesamiento.")
                except Exception as e_preproc:
                    print(f"      Error durante el preprocesamiento del segmento {path_segmento_guardado}: {e_preproc}. Usando segmento original.")
                    # Si falla el preprocesamiento, asegúrate de usar la imagen PIL original
                    imagen_a_procesar_pil = segmento_pil
                    identificador_imagen = path_segmento_guardado

            else:
                print("      Preprocesamiento desactivado para este segmento.")
                # Si el preprocesamiento general está desactivado, usar la imagen PIL original
                imagen_a_procesar_pil = segmento_pil
                identificador_imagen = path_segmento_guardado


            # Llamar a la función de extracción con la imagen (original o preprocesada)
            datos_segmento = extract_data_from_image_gemini_v_few_shot_pil(imagen_a_procesar_pil,
                                                                         target_dia_pago="31.12.2017",
                                                                         image_identifier=identificador_imagen)

            if datos_segmento:
                if isinstance(datos_segmento, list):
                    todos_los_datos_extraidos_pagina.extend(datos_segmento)
                else:
                    print(f"      Advertencia: Se esperaba una lista del segmento {identificador_imagen}, pero se obtuvo: {type(datos_segmento)}. Datos: {datos_segmento}")
            else:
                print(f"      No se extrajeron datos del segmento {identificador_imagen}.")

    return todos_los_datos_extraidos_pagina

# %%
# CELDA NUEVA: Cargar y preparar la lista de meses/años a ignorar
import pandas as pd

ignore_csv_path = '/content/drive/MyDrive/DEUDA_PREVISIONAL/años_noconsiderar_2017/missing_year_months.csv' # Asegúrate que esta ruta sea correcta

try:
    df_ignore = pd.read_csv(ignore_csv_path)

    meses_map_num_to_nombre = {
        1: "ENERO", 2: "FEBRERO", 3: "MARZO", 4: "ABRIL", 5: "MAYO", 6: "JUNIO",
        7: "JULIO", 8: "AGOSTO", 9: "SEPTIEMBRE", 10: "OCTUBRE", 11: "NOVIEMBRE", 12: "DICIEMBRE"
    }

    def format_ignore_date(date_str_yyyy_mm):
        if pd.isna(date_str_yyyy_mm):
            return None
        try:
            year, month = map(int, date_str_yyyy_mm.split('-'))
            month_name = meses_map_num_to_nombre.get(month)
            if month_name:
                return f"{month_name} {year}"
            return None
        except Exception as e:
            print(f"Error formateando fecha a ignorar '{date_str_yyyy_mm}': {e}")
            return None

    if 'missing_year_month' in df_ignore.columns:
        df_ignore['formatted_ignore_date'] = df_ignore['missing_year_month'].apply(format_ignore_date)
        ignore_set = set(df_ignore['formatted_ignore_date'].dropna())
        print(f"Se cargarán {len(ignore_set)} meses/años para ignorar.")
        print("Primeros 5 meses/años a ignorar (formateados):", list(ignore_set)[:5])
    else:
        print(f"Error: La columna 'missing_year_month' no se encontró en {ignore_csv_path}")
        ignore_set = set()

except FileNotFoundError:
    print(f"Error: No se encontró el archivo CSV '{ignore_csv_path}'. No se ignorará ningún mes/año adicional.")
    ignore_set = set()
except Exception as e:
    print(f"Ocurrió un error al procesar el archivo CSV de ignorados: {e}")
    ignore_set = set()
# Out:
# Se cargarán 54 meses/años para ignorar.
# Primeros 5 meses/años a ignorar (formateados): ['ENERO 2000', 'SEPTIEMBRE 2002', 'MAYO 2002', 'AGOSTO 2002', 'JUNIO 2011']

# %%
# CELDA DEL BUCLE PRINCIPAL DE PROCESAMIENTO (MODIFICADA CON FILTRO Y OPCIÓN DE PREPROCESAMIENTO)

all_extracted_data_final = []
if not image_paths:
    print("No hay imágenes de página completa para procesar.")
else:
    # Procesar solo las primeras N páginas para pruebas rápidas, o todas con image_paths
    paginas_a_procesar = image_paths # <<< CAMBIA ESTO

    # Procesar solo las páginas con nombres específicos si están en image_paths
    # nombres_especificos = ['page_1.png', 'page_2.png']
    # paginas_a_procesar = [p for p in image_paths if os.path.basename(p) in nombres_especificos]

if not paginas_a_procesar:
    # print(f"Advertencia: No se encontraron las páginas '{nombres_especificos}' en la lista de imágenes encontradas.")
    if image_paths:
         print(f"Imágenes encontradas: {[os.path.basename(p) for p in image_paths]}")
    else:
         print("No se encontraron imágenes en la carpeta especificada.")
else:
    print(f"Se procesarán las siguientes páginas: {[os.path.basename(p) for p in paginas_a_procesar]}")

    for pagina_img_path in paginas_a_procesar:
        print(f"\n--- Procesando página completa: {pagina_img_path} ---")

        # --- CONFIGURACIÓN DEL PROCESAMIENTO DE LA PÁGINA Y PREPROCESAMIENTO ---
        num_segmentos = 2
        superposicion = 188
        aplicar_preproc_general = False # Flag general para activar/desactivar todo el preprocesamiento

        # Flags específicos para cada paso (solo se consideran si aplicar_preproc_general es True)
        usar_upscaling = False
        factor_upscale = 1.5
        usar_escala_grises = True # Generalmente recomendado para thresholding
        usar_clahe = True
        clip_limit_clahe_val = 2.0
        tile_grid_clahe_val = (8,8)
        usar_thresholding_adaptativo = False
        block_size_thresh_val = 11
        c_value_thresh_val = 2
        usar_denoising_mediano = False
        kernel_size_denoising_val = 3
        usar_nitidez = False # Usar con precaución

        print(f"Usando num_segmentos_verticales_por_tabla={num_segmentos}, overlap_px={superposicion}")
        print(f"Configuración de Preprocesamiento: General={aplicar_preproc_general}, Upscaling={usar_upscaling}, Gris={usar_escala_grises}, CLAHE={usar_clahe}, Thresholding={usar_thresholding_adaptativo}, Denoising={usar_denoising_mediano}, Nitidez={usar_nitidez}")


        datos_de_pagina_segmentada = segmentar_y_procesar_pagina_v2(
            pagina_img_path,
            num_segmentos_verticales_por_tabla=num_segmentos,
            overlap_px=superposicion,
            aplicar_preprocesamiento=aplicar_preproc_general, # Pasar el flag general
            aplicar_upscaling=usar_upscaling,
            factor_upscaling=factor_upscale,
            aplicar_escala_grises=usar_escala_grises,
            aplicar_clahe=usar_clahe,
            clip_limit_clahe=clip_limit_clahe_val,
            tile_grid_clahe=tile_grid_clahe_val,
            aplicar_thresholding_adaptativo=usar_thresholding_adaptativo,
            block_size_thresh=block_size_thresh_val,
            c_value_thresh=c_value_thresh_val,
            aplicar_denoising_mediano=usar_denoising_mediano,
            kernel_size_denoising=kernel_size_denoising_val,
            aplicar_nitidez=usar_nitidez
        )

        if datos_de_pagina_segmentada:
            all_extracted_data_final.extend(datos_de_pagina_segmentada)
        print(f"--- Fin del procesamiento para la página: {pagina_img_path} ---")


# ----- INICIO DE LA MODIFICACIÓN PARA FILTRAR -----
print(f"\nTotal de items extraídos antes de filtrar por CSV: {len(all_extracted_data_final)}")
if 'ignore_set' in globals() and ignore_set:
    all_extracted_data_temp_filtered = []
    for item_idx, item in enumerate(all_extracted_data_final):
        if isinstance(item, dict) and "mes_año_columna" in item:
            mes_ano_item_upper = str(item["mes_año_columna"]).upper()
            if mes_ano_item_upper.startswith("CIEMBRE "):
                mes_ano_item_upper = "DICIEMBRE " + mes_ano_item_upper.split(" ")[-1]
            if mes_ano_item_upper not in ignore_set:
                all_extracted_data_temp_filtered.append(item)
            else:
                print(f"  Item ignorado (de CSV): {item['mes_año_columna']} (comparado como {mes_ano_item_upper})")
        else:
            all_extracted_data_temp_filtered.append(item)
    all_extracted_data_final = all_extracted_data_temp_filtered
    print(f"Total de items después de filtrar por CSV: {len(all_extracted_data_final)}")
else:
    print("No se aplicó filtro por CSV (ignore_set no definido o vacío).")
# ----- FIN DE LA MODIFICACIÓN PARA FILTRAR -----

print("\n\n--- DATOS EXTRAÍDOS FINALES (segmentados y filtrados por CSV) ---")
if all_extracted_data_final:
    datos_unicos_temp = {}
    items_validos_para_deduplicacion = [item for item in all_extracted_data_final if isinstance(item, dict) and "mes_año_columna" in item]
    print(f"Total de items válidos para deduplicación: {len(items_validos_para_deduplicacion)}")

    for item_idx, item in enumerate(items_validos_para_deduplicacion):
        if isinstance(item, dict) and "mes_año_columna" in item:
            clave_unica_original = item["mes_año_columna"]
            clave_unica = str(clave_unica_original).upper()
            if clave_unica.startswith("CIEMBRE "):
                 clave_unica = "DICIEMBRE " + clave_unica.split(" ")[-1]

            def contar_nones(data_item):
                count = 0
                if not isinstance(data_item, dict): return 3
                if data_item.get("interes_afiliado_porcentaje") is None: count +=1
                if data_item.get("recargo_beneficio_afiliado_porcentaje") is None: count +=1
                if data_item.get("reajuste_porcentaje") is None: count +=1
                return count

            if clave_unica not in datos_unicos_temp:
                datos_unicos_temp[clave_unica] = item
            else:
                existente = datos_unicos_temp[clave_unica]
                nuevo = item
                nones_existente = contar_nones(existente)
                nones_nuevo = contar_nones(nuevo)
                if nones_nuevo < nones_existente:
                    print(f"  ACTUALIZANDO {clave_unica_original} (clave: {clave_unica}): Nueva versión tiene menos Nones ({nones_nuevo} vs {nones_existente}).")
                    datos_unicos_temp[clave_unica] = nuevo
    all_extracted_data_final_unicos = list(datos_unicos_temp.values())
    print(f"Total de items después de deduplicación: {len(all_extracted_data_final_unicos)}\n")

    def obtener_clave_ordenamiento(item):
        try:
            partes = item['mes_año_columna'].split()
            mes_str = partes[0]
            año_str = partes[1]
            meses_map = {"ENERO": 1, "FEBRERO": 2, "MARZO": 3, "ABRIL": 4, "MAYO": 5, "JUNIO": 6,
                         "JULIO": 7, "AGOSTO": 8, "SEPTIEMBRE": 9, "OCTUBRE": 10, "NOVIEMBRE": 11, "DICIEMBRE": 12,
                         "CIEMBRE": 12}
            mes_num = meses_map.get(mes_str.upper(), 0)
            return (int(año_str), mes_num)
        except:
            return (9999, 99)

    if all_extracted_data_final_unicos and isinstance(all_extracted_data_final_unicos[0], dict) and 'mes_año_columna' in all_extracted_data_final_unicos[0]:
       all_extracted_data_final_unicos.sort(key=obtener_clave_ordenamiento)
       print("  Datos reordenados cronológicamente.")

    for item in all_extracted_data_final_unicos:
        print(item)

    try:
        df_final = pd.DataFrame(all_extracted_data_final_unicos)
        print("\n--- DataFrame de Pandas (segmentado, filtrado y deduplicado) ---")
        print(df_final.to_string()) # Usar to_string() para ver más filas si es necesario

        # El guardado a Excel se moverá a la celda de comparación o alertas.
    except ImportError:
        print("\nPandas no está instalado. No se puede crear el DataFrame.")
    except Exception as e:
        print(f"Error al crear o mostrar el DataFrame final: {e}")
else:
    print("No se extrajeron datos o todos fueron filtrados/deduplicados (all_extracted_data_final_unicos está vacío).")
    df_final = pd.DataFrame() # Asegurarse que df_final exista como DataFrame vacío si no hay datos
# Out:
# Se procesarán las siguientes páginas: ['page_1.png', 'page_2.png', 'page_3.png', 'page_4.png', 'page_5.png', 'page_6.png', 'page_7.png', 'page_8.png', 'page_9.png', 'page_10.png', 'page_11.png', 'page_12.png', 'page_13.png', 'page_14.png', 'page_15.png', 'page_16.png', 'page_17.png', 'page_18.png', 'page_19.png', 'page_20.png', 'page_21.png', 'page_22.png', 'page_23.png', 'page_24.png', 'page_25.png', 'page_26.png', 'page_27.png', 'page_28.png', 'page_29.png', 'page_30.png', 'page_31.png']
#
# --- Procesando página completa: /content/drive/MyDrive/DEUDA_PREVISIONAL/PDFS/2017/page_1.png ---
# Usando num_segmentos_verticales_por_tabla=2, overlap_px=188
# Configuración de Preprocesamiento: General=False, Upscaling=False, Gris=True, CLAHE=True, Thresholding=False, Denoising=False, Nitidez=False
#
# Procesando sección de tabla horizontal 1 (Y: 0-1616) de page_1.png
#     Procesando segmento vertical 1 de la sección 1 (Global ID: 1): X[0-1462], Y[0-1616]
#       Segmento original guardado en: segmentos_guardados/page_1_tabla1_seg1_orig.png
#       Preprocesamiento desactivado para este segmento.
#
# Procesando imagen: segmentos_guardados/page_1_tabla1_seg1_orig.png con Gemini, prompt v_few_shot (con énfasis anti-omisión)...
# Respuesta cruda de Gemini para segmentos_guardados/page_1_tabla1_seg1_orig.png:
# ```json
# [
#   {
#     "mes_año_columna": "MAYO 1997",
#     "reajuste_porcentaje": "13.70%",
#     "interes_afiliado_porcentaje": "3293.80%",
#     "recargo_beneficio_afiliado_porcentaje": "658.76%"
#   },
#   {
#     "mes_año_columna": "JUNIO 1997",
#     "reajuste_porcentaje": "13.70%",
#     "interes_afiliado_porcentaje": "3250.14%",
#     "recargo_beneficio_afiliado_porcentaje": "650.03%"
#   },
#   {
#     "mes_año_columna": "JULIO 1997",
#     "reajuste_porcentaje": "13.70%",
#     "interes_afiliado_porcentaje": "3207.96%",
#     "recargo_beneficio_afiliado_porcentaje": "641.59%"
#   }
# ]
# ```
#
#     Procesando segmento vertical 2 de la sección 1 (Global ID: 2): X[1086-2548], Y[0-1616]
#       Segmento original guardado en: segmentos_guardados/page_1_tabla1_seg2_orig.png
#       Preprocesamiento desactivado para este segmento.
#
# Procesando imagen: segmentos_guardados/page_1_tabla1_seg2_orig.png con Gemini, prompt v_few_shot (con énfasis anti-omisión)...
# Respuesta cruda de Gemini para segmentos_guardados/page_1_tabla1_seg2_orig.png:
# ```json
# [
#   {
#     "mes_año_columna": "JULIO 1997",
#     "reajuste_porcentaje": "13.70%",
#     "interes_afiliado_porcentaje": "3207.96%",
#     "recargo_beneficio_afiliado_porcentaje": "641.59%"
#   },
#   {
#     "mes_año_columna": "AGOSTO 1997",
#     "reajuste_porcentaje": "13.48%",
#     "interes_afiliado_porcentaje": "3171.91%",
#     "recargo_beneficio_afiliado_porcentaje": "634.38%"
#   },
#   {
#     "mes_año_columna": "SEPTIEMBRE 1997",
#     "reajuste_porcentaje": "13.01%",
#     "interes_afiliado_porcentaje": "3143.02%",
#     "recargo_beneficio_afiliado_porcentaje": "628.60%"
#   }
# ]
# ```
#
#
# Procesando sección de tabla horizontal 2 (Y: 1616-3298) de page_1.png
#     Procesando segmento vertical 1 de la sección 2 (Global ID: 3): X[0-1462], Y[1616-3298]
#       Segmento original guardado en: segmentos_guardados/page_1_tabla2_seg1_orig.png
#       Preprocesamiento desactivado para este segmento.
#
# Procesando imagen: segmentos_guardados/page_1_tabla2_seg1_orig.png con Gemini, prompt v_few_shot (con énfasis anti-omisión)...
# Respuesta cruda de Gemini para segmentos_guardados/page_1_tabla2_seg1_orig.png:
# ```json
# [
#   {
#     "mes_año_columna": "OCTUBRE 1997",
#     "reajuste_porcentaje": "12.69%",
#     "interes_afiliado_porcentaje": "3110.70%",
#     "recargo_beneficio_afiliado_porcentaje": "622.14%"
#   },
#   {
#     "mes_año_columna": "NOVIEMBRE 1997",
#     "reajuste_porcentaje": "11.58%",
#     "interes_afiliado_porcentaje": "3088.33%",
#     "recargo_beneficio_afiliado_porcentaje": "617.67%"
#   },
#   {
#     "mes_año_columna": "DICIEMBRE 1997",
#     "reajuste_porcentaje": "10.70%",
#     "interes_afiliado_porcentaje": "3053.74%",
#     "recargo_beneficio_afiliado_porcentaje": "610.75%"
#   }
# ]
# ```
#
#     Procesando segmento vertical 2 de la sección 2 (Global ID: 4): X[1086-2548], Y[1616-3298]
#       Segmento original guardado en: segmentos_guardados/page_1_tabla2_seg2_orig.png
#       Preprocesamiento desactivado para este segmento.
#
# Procesando imagen: segmentos_guardados/page_1_tabla2_seg2_orig.png con Gemini, prompt v_few_shot (con énfasis anti-omisión)...
# Respuesta cruda de Gemini para segmentos_guardados/page_1_tabla2_seg2_orig.png:
# ```json
# [
#   {
#     "mes_año_columna": "DICIEMBRE 1997",
#     "reajuste_porcentaje": "10.70%",
#     "interes_afiliado_porcentaje": "3053.74%",
#     "recargo_beneficio_afiliado_porcentaje": "610.75%"
#   },
#   {
#     "mes_año_columna": "ENERO 1998",
#     "reajuste_porcentaje": "10.70%",
#     "interes_afiliado_porcentaje": "3006.95%",
#     "recargo_beneficio_afiliado_porcentaje": "601.39%"
#   },
#   {
#     "mes_año_columna": "FEBRERO 1998",
#     "reajuste_porcentaje": "10.44%",
#     "interes_afiliado_porcentaje": "2971.31%",
#     "recargo_beneficio_afiliado_porcentaje": "594.26%"
#   }
# ]
# ```
#
# --- Fin del procesamiento para la página: /content/drive/MyDrive/DEUDA_PREVISIONAL/PDFS/2017/page_1.png ---
#
# --- Procesando página completa: /content/drive/MyDrive/DEUDA_PREVISIONAL/PDFS/2017/page_2.png ---
# Usando num_segmentos_verticales_por_tabla=2, overlap_px=188
# Configuración de Preprocesamiento: General=False, Upscaling=False, Gris=True, CLAHE=True, Thresholding=False, Denoising=False, Nitidez=False
#
# Procesando sección de tabla horizontal 1 (Y: 0-1616) de page_2.png
#     Procesando segmento vertical 1 de la sección 1 (Global ID: 1): X[0-1466], Y[0-1616]
#       Segmento original guardado en: segmentos_guardados/page_2_tabla1_seg1_orig.png
#       Preprocesamiento desactivado para este segmento.
#
# Procesando imagen: segmentos_guardados/page_2_tabla1_seg1_orig.png con Gemini, prompt v_few_shot (con énfasis anti-omisión)...
# Respuesta cruda de Gemini para segmentos_guardados/page_2_tabla1_seg1_orig.png:
# ```json
# [
#   {
#     "mes_año_columna": "MARZO 1998",
#     "reajuste_porcentaje": "9.92%",
#     "interes_afiliado_porcentaje": "2921.98%",
#     "recargo_beneficio_afiliado_porcentaje": "584.40%"
#   },
#   {
#     "mes_año_columna": "ABRIL 1998",
#     "reajuste_porcentaje": "9.92%",
#     "interes_afiliado_porcentaje": "2861.70%",
#     "recargo_beneficio_afiliado_porcentaje": "572.34%"
#   },
#   {
#     "mes_año_columna": "MAYO 1998",
#     "reajuste_porcentaje": "9.78%",
#     "interes_afiliado_porcentaje": "2821.42%",
#     "recargo_beneficio_afiliado_porcentaje": "564.28%"
#   }
# ]
# ```
#
#     Procesando segmento vertical 2 de la sección 1 (Global ID: 2): X[1090-2556], Y[0-1616]
#       Segmento original guardado en: segmentos_guardados/page_2_tabla1_seg2_orig.png
#       Preprocesamiento desactivado para este segmento.
#
# Procesando imagen: segmentos_guardados/page_2_tabla1_seg2_orig.png con Gemini, prompt v_few_shot (con énfasis anti-omisión)...
# Respuesta cruda de Gemini para segmentos_guardados/page_2_tabla1_seg2_orig.png:
# ```json
# [
#   {
#     "mes_año_columna": "MAYO 1998",
#     "reajuste_porcentaje": "9.78%",
#     "interes_afiliado_porcentaje": "2799.14%",
#     "recargo_beneficio_afiliado_porcentaje": "559.83%"
#   },
#   {
#     "mes_año_columna": "JUNIO 1998",
#     "reajuste_porcentaje": "9.47%",
#     "interes_afiliado_porcentaje": "2772.00%",
#     "recargo_beneficio_afiliado_porcentaje": "554.40%"
#   },
#   {
#     "mes_año_columna": "JULIO 1998",
#     "reajuste_porcentaje": "9.47%",
#     "interes_afiliado_porcentaje": "2755.15%",
#     "recargo_beneficio_afiliado_porcentaje": "551.03%"
#   }
# ]
# ```
#
# Procesando sección de tabla horizontal 2 (Y: 1616-3298) de page_2.png
#     Procesando segmento vertical 1 de la sección 2 (Global ID: 3): X[0-1466], Y[1616-3298]
#       Segmento original guardado en: segmentos_guardados/page_2_tabla2_seg1_orig.png
#       Preprocesamiento desactivado para este segmento.
#
# Procesando imagen: segmentos_guardados/page_2_tabla2_seg1_orig.png con Gemini, prompt v_few_shot (con énfasis anti-omisión)...
# Respuesta cruda de Gemini para segmentos_guardados/page_2_tabla2_seg1_orig.png:
# ```json
# [
#   {
#     "mes_año_columna": "AGOSTO 1998",
#     "reajuste_porcentaje": "9.47%",
#     "interes_afiliado_porcentaje": "2714.92%",
#     "recargo_beneficio_afiliado_porcentaje": "542.98%"
#   },
#   {
#     "mes_año_columna": "SEPTIEMBRE 1998",
#     "reajuste_porcentaje": "9.47%",
#     "interes_afiliado_porcentaje": "2663.63%",
#     "recargo_beneficio_afiliado_porcentaje": "532.73%"
#   },
#   {
#     "mes_año_columna": "OCTUBRE 1998",
#     "reajuste_porcentaje": "9.47%",
#     "interes_afiliado_porcentaje": "2615.84%",
#     "recargo_beneficio_afiliado_porcentaje": "523.17%"
#   }
# ]
# ```
#
#     Procesando segmento vertical 2 de la sección 2 (Global ID: 4): X[1090-2556], Y[1616-3298]
#       Segmento original guardado en: segmentos_guardados/page_2_tabla2_seg2_orig.png
#       Preprocesamiento desactivado para este segmento.
#
# Procesando imagen: segmentos_guardados/page_2_tabla2_seg2_orig.png con Gemini, prompt v_few_shot (con énfasis anti-omisión)...
# Respuesta cruda de Gemini para segmentos_guardados/page_2_tabla2_seg2_orig.png:
# ```json
# [
#   {
#     "mes_año_columna": "OCTUBRE 1998",
#     "reajuste_porcentaje": "9.47%",
#     "interes_afiliado_porcentaje": "2615.84%",
#     "recargo_beneficio_afiliado_porcentaje": "523.17%"
#   },
#   {
#     "mes_año_columna": "NOVIEMBRE 1998",
#     "reajuste_porcentaje": "9.47%",
#     "interes_afiliado_porcentaje": "2560.79%",
#     "recargo_beneficio_afiliado_porcentaje": "512.16%"
#   },
#   {
#     "mes_año_columna": "DICIEMBRE 1998",
#     "reajuste_porcentaje": "9.47%",
#     "interes_afiliado_porcentaje": "2498.89%",
#     "recargo_beneficio_afiliado_porcentaje": "499.78%"
#   }
# ]
# ```
#
# --- Fin del procesamiento para la página: /content/drive/MyDrive/DEUDA_PREVISIONAL/PDFS/2017/page_2.png ---
#
# --- Procesando página completa: /content/drive/MyDrive/DEUDA_PREVISIONAL/PDFS/2017/page_3.png ---
# Usando num_segmentos_verticales_por_tabla=2, overlap_px=188
# Configuración de Preprocesamiento: General=False, Upscaling=False, Gris=True, CLAHE=True, Thresholding=False, Denoising=False, Nitidez=False
#
# Procesando sección de tabla horizontal 1 (Y: 0-1616) de page_3.png
#     Procesando segmento vertical 1 de la sección 1 (Global ID: 1): X[0-1466], Y[0-1616]
#       Segmento original guardado en: segmentos_guardados/page_3_tabla1_seg1_orig.png
#       Preprocesamiento desactivado para este segmento.
#
# Procesando imagen: segmentos_guardados/page_3_tabla1_seg1_orig.png con Gemini, prompt v_few_shot (con énfasis anti-omisión)...
# Respuesta cruda de Gemini para segmentos_guardados/page_3_tabla1_seg1_orig.png:
# ```json
# [
#   {
#     "mes_año_columna": "ENERO 1999",
#     "reajuste_porcentaje": "9.47%",
#     "interes_afiliado_porcentaje": "2452.21%",
#     "recargo_beneficio_afiliado_porcentaje": "490.44%"
#   },
#   {
#     "mes_año_columna": "FEBRERO 1999",
#     "reajuste_porcentaje": "9.47%",
#     "interes_afiliado_porcentaje": "2418.62%",
#     "recargo_beneficio_afiliado_porcentaje": "483.72%"
#   },
#   {
#     "mes_año_columna": "MARZO 1999",
#     "reajuste_porcentaje": "9.47%",
#     "interes_afiliado_porcentaje": "2384.41%",
#     "recargo_beneficio_afiliado_porcentaje": "476.88%"
#   }
# ]
# ```
#
#     Procesando segmento vertical 2 de la sección 1 (Global ID: 2): X[1090-2556], Y[0-1616]
#       Segmento original guardado en: segmentos_guardados/page_3_tabla1_seg2_orig.png
#       Preprocesamiento desactivado para este segmento.
#
# Procesando imagen: segmentos_guardados/page_3_tabla1_seg2_orig.png con Gemini, prompt v_few_shot (con énfasis anti-omisión)...
# Respuesta cruda de Gemini para segmentos_guardados/page_3_tabla1_seg2_orig.png:
# ```json
# [
#   {
#     "mes_año_columna": "MARZO 1999",
#     "reajuste_porcentaje": "9.47%",
#     "interes_afiliado_porcentaje": "2379.67%",
#     "recargo_beneficio_afiliado_porcentaje": "475.93%"
#   },
#   {
#     "mes_año_columna": "ABRIL 1999",
#     "reajuste_porcentaje": "9.27%",
#     "interes_afiliado_porcentaje": "2360.35%",
#     "recargo_beneficio_afiliado_porcentaje": "472.07%"
#   },
#   {
#     "mes_año_columna": "MAYO 1999",
#     "reajuste_porcentaje": "8.69%",
#     "interes_afiliado_porcentaje": "2340.97%",
#     "recargo_beneficio_afiliado_porcentaje": "468.19%"
#   }
# ]
# ```
#
#
# Procesando sección de tabla horizontal 2 (Y: 1616-3298) de page_3.png
#     Procesando segmento vertical 1 de la sección 2 (Global ID: 3): X[0-1466], Y[1616-3298]
#       Segmento original guardado en: segmentos_guardados/page_3_tabla2_seg1_orig.png
#       Preprocesamiento desactivado para este segmento.
#
# Procesando imagen: segmentos_guardados/page_3_tabla2_seg1_orig.png con Gemini, prompt v_few_shot (con énfasis anti-omisión)...
# Respuesta cruda de Gemini para segmentos_guardados/page_3_tabla2_seg1_orig.png:
# ```json
# [
#   {
#     "mes_año_columna": "JUNIO 1999",
#     "reajuste_porcentaje": "8.39%",
#     "interes_afiliado_porcentaje": "2289.64%",
#     "recargo_beneficio_afiliado_porcentaje": "457.93%"
#   },
#   {
#     "mes_año_columna": "JULIO 1999",
#     "reajuste_porcentaje": "8.39%",
#     "interes_afiliado_porcentaje": "2254.88%",
#     "recargo_beneficio_afiliado_porcentaje": "450.98%"
#   },
#   {
#     "mes_año_columna": "AGOSTO 1999",
#     "reajuste_porcentaje": "8.39%",
#     "interes_afiliado_porcentaje": "2209.98%",
#     "recargo_beneficio_afiliado_porcentaje": "442.00%"
#   }
# ]
# ```
#     Procesando segmento vertical 2 de la sección 2 (Global ID: 4): X[1090-2556], Y[1616-3298]
#       Segmento original guardado en: segmentos_guardados/page_3_tabla2_seg2_orig.png
#       Preprocesamiento desactivado para este segmento.
#
# Procesando imagen: segmentos_guardados/page_3_tabla2_seg2_orig.png con Gemini, prompt v_few_shot (con énfasis anti-omisión)...
# Respuesta cruda de Gemini para segmentos_guardados/page_3_tabla2_seg2_orig.png:
# ```json
# [
#   {
#     "mes_año_columna": "AGOSTO 1999",
#     "reajuste_porcentaje": "8.39%",
#     "interes_afiliado_porcentaje": "2238.41%",
#     "recargo_beneficio_afiliado_porcentaje": "447.68%"
#   },
#   {
#     "mes_año_columna": "SEPTIEMBRE 1999",
#     "reajuste_porcentaje": "8.39%",
#     "interes_afiliado_porcentaje": "2201.06%",
#     "recargo_beneficio_afiliado_porcentaje": "440.21%"
#   },
#   {
#     "mes_año_columna": "OCTUBRE 1999",
#     "reajuste_porcentaje": "8.39%",
#     "interes_afiliado_porcentaje": "2162.56%",
#     "recargo_beneficio_afiliado_porcentaje": "432.51%"
#   }
# ]
# ```
#
# --- Fin del procesamiento para la página: /content/drive/MyDrive/DEUDA_PREVISIONAL/PDFS/2017/page_3.png ---
#
# --- Procesando página completa: /content/drive/MyDrive/DEUDA_PREVISIONAL/PDFS/2017/page_4.png ---
# Usando num_segmentos_verticales_por_tabla=2, overlap_px=188
# Configuración de Preprocesamiento: General=False, Upscaling=False, Gris=True, CLAHE=True, Thresholding=False, Denoising=False, Nitidez=False
#
# Procesando sección de tabla horizontal 1 (Y: 0-1616) de page_4.png
#     Procesando segmento vertical 1 de la sección 1 (Global ID: 1): X[0-1463], Y[0-1616]
#       Segmento original guardado en: segmentos_guardados/page_4_tabla1_seg1_orig.png
#       Preprocesamiento desactivado para este segmento.
#
# Procesando imagen: segmentos_guardados/page_4_tabla1_seg1_orig.png con Gemini, prompt v_few_shot (con énfasis anti-omisión)...
# Respuesta cruda de Gemini para segmentos_guardados/page_4_tabla1_seg1_orig.png:
# ```json
# [
#   {
#     "mes_año_columna": "NOVIEMBRE 1999",
#     "reajuste_porcentaje": "8.39%",
#     "interes_afiliado_porcentaje": "2083.69%",
#     "recargo_beneficio_afiliado_porcentaje": "416.74%"
#   },
#   {
#     "mes_año_columna": "DICIEMBRE 1999",
#     "reajuste_porcentaje": "8.39%",
#     "interes_afiliado_porcentaje": "2048.86%",
#     "recargo_beneficio_afiliado_porcentaje": "409.77%"
#   },
#   {
#     "mes_año_columna": "ENERO 2000",
#     "reajuste_porcentaje": "8.39%",
#     "interes_afiliado_porcentaje": "2007.89%",
#     "recargo_beneficio_afiliado_porcentaje": "401.58%"
#   }
# ]
# ```
#
#     Procesando segmento vertical 2 de la sección 1 (Global ID: 2): X[1087-2550], Y[0-1616]
#       Segmento original guardado en: segmentos_guardados/page_4_tabla1_seg2_orig.png
#       Preprocesamiento desactivado para este segmento.
#
# Procesando imagen: segmentos_guardados/page_4_tabla1_seg2_orig.png con Gemini, prompt v_few_shot (con énfasis anti-omisión)...
# Respuesta cruda de Gemini para segmentos_guardados/page_4_tabla1_seg2_orig.png:
# ```json
# [
#   {
#     "mes_año_columna": "ENERO 2000",
#     "reajuste_porcentaje": "8.39%",
#     "interes_afiliado_porcentaje": "2048.86%",
#     "recargo_beneficio_afiliado_porcentaje": "409.77%"
#   },
#   {
#     "mes_año_columna": "FEBRERO 2000",
#     "reajuste_porcentaje": "8.39%",
#     "interes_afiliado_porcentaje": "2016.72%",
#     "recargo_beneficio_afiliado_porcentaje": "403.34%"
#   },
#   {
#     "mes_año_columna": "MARZO 2000",
#     "reajuste_porcentaje": "8.39%",
#     "interes_afiliado_porcentaje": "1981.59%",
#     "recargo_beneficio_afiliado_porcentaje": "396.32%"
#   }
# ]
# ```
#
#
# Procesando sección de tabla horizontal 2 (Y: 1616-3298) de page_4.png
#     Procesando segmento vertical 1 de la sección 2 (Global ID: 3): X[0-1463], Y[1616-3298]
#       Segmento original guardado en: segmentos_guardados/page_4_tabla2_seg1_orig.png
#       Preprocesamiento desactivado para este segmento.
#
# Procesando imagen: segmentos_guardados/page_4_tabla2_seg1_orig.png con Gemini, prompt v_few_shot (con énfasis anti-omisión)...
# Respuesta cruda de Gemini para segmentos_guardados/page_4_tabla2_seg1_orig.png:
# ```json
# [
#   {
#     "mes_año_columna": "MAYO 2000",
#     "reajuste_porcentaje": "8.39%",
#     "interes_afiliado_porcentaje": "1924.73%",
#     "recargo_beneficio_afiliado_porcentaje": "384.95%"
#   },
#   {
#     "mes_año_columna": "JUNIO 2000",
#     "reajuste_porcentaje": "8.39%",
#     "interes_afiliado_porcentaje": "1901.46%",
#     "recargo_beneficio_afiliado_porcentaje": "380.29%"
#   }
# ]
# ```
#
#     Procesando segmento vertical 2 de la sección 2 (Global ID: 4): X[1087-2550], Y[1616-3298]
#       Segmento original guardado en: segmentos_guardados/page_4_tabla2_seg2_orig.png
#       Preprocesamiento desactivado para este segmento.
#
# Procesando imagen: segmentos_guardados/page_4_tabla2_seg2_orig.png con Gemini, prompt v_few_shot (con énfasis anti-omisión)...
# Respuesta cruda de Gemini para segmentos_guardados/page_4_tabla2_seg2_orig.png:
# ```json
# [
#   {
#     "mes_año_columna": "JUNIO 2000",
#     "reajuste_porcentaje": "8.39%",
#     "interes_afiliado_porcentaje": "1876.02%",
#     "recargo_beneficio_afiliado_porcentaje": "375.20%"
#   },
#   {
#     "mes_año_columna": "JULIO 2000",
#     "reajuste_porcentaje": "8.39%",
#     "interes_afiliado_porcentaje": "1877.29%",
#     "recargo_beneficio_afiliado_porcentaje": "375.46%"
#   },
#   {
#     "mes_año_columna": "AGOSTO 2000",
#     "reajuste_porcentaje": "8.39%",
#     "interes_afiliado_porcentaje": "1878.57%",
#     "recargo_beneficio_afiliado_porcentaje": "375.71%"
#   }
# ]
# ```
#
# --- Fin del procesamiento para la página: /content/drive/MyDrive/DEUDA_PREVISIONAL/PDFS/2017/page_4.png ---
#
# --- Procesando página completa: /content/drive/MyDrive/DEUDA_PREVISIONAL/PDFS/2017/page_5.png ---
# Usando num_segmentos_verticales_por_tabla=2, overlap_px=188
# Configuración de Preprocesamiento: General=False, Upscaling=False, Gris=True, CLAHE=True, Thresholding=False, Denoising=False, Nitidez=False
#
# Procesando sección de tabla horizontal 1 (Y: 0-1616) de page_5.png
#     Procesando segmento vertical 1 de la sección 1 (Global ID: 1): X[0-1463], Y[0-1616]
#       Segmento original guardado en: segmentos_guardados/page_5_tabla1_seg1_orig.png
#       Preprocesamiento desactivado para este segmento.
#
# Procesando imagen: segmentos_guardados/page_5_tabla1_seg1_orig.png con Gemini, prompt v_few_shot (con énfasis anti-omisión)...
# Respuesta cruda de Gemini para segmentos_guardados/page_5_tabla1_seg1_orig.png:
# ```json
# [
#   {
#     "mes_año_columna": "SEPTIEMBRE 2000",
#     "reajuste_porcentaje": "8.39%",
#     "interes_afiliado_porcentaje": "1821.98%",
#     "recargo_beneficio_afiliado_porcentaje": "364.40%"
#   },
#   {
#     "mes_año_columna": "OCTUBRE 2000",
#     "reajuste_porcentaje": "8.39%",
#     "interes_afiliado_porcentaje": "1792.05%",
#     "recargo_beneficio_afiliado_porcentaje": "358.41%"
#   },
#   {
#     "mes_año_columna": "NOVIEMBRE 2000",
#     "reajuste_porcentaje": "8.39%",
#     "interes_afiliado_porcentaje": "1761.25%",
#     "recargo_beneficio_afiliado_porcentaje": "352.25%"
#   }
# ]
# ```
#
#     Procesando segmento vertical 2 de la sección 1 (Global ID: 2): X[1087-2550], Y[0-1616]
#       Segmento original guardado en: segmentos_guardados/page_5_tabla1_seg2_orig.png
#       Preprocesamiento desactivado para este segmento.
#
# Procesando imagen: segmentos_guardados/page_5_tabla1_seg2_orig.png con Gemini, prompt v_few_shot (con énfasis anti-omisión)...
# Respuesta cruda de Gemini para segmentos_guardados/page_5_tabla1_seg2_orig.png:
# ```json
# [
#   {
#     "mes_año_columna": "NOVIEMBRE 2000",
#     "reajuste_porcentaje": "8.39%",
#     "interes_afiliado_porcentaje": "1761.25%",
#     "recargo_beneficio_afiliado_porcentaje": "352.25%"
#   },
#   {
#     "mes_año_columna": "DICIEMBRE 2000",
#     "reajuste_porcentaje": "8.39%",
#     "interes_afiliado_porcentaje": "1730.59%",
#     "recargo_beneficio_afiliado_porcentaje": "346.12%"
#   },
#   {
#     "mes_año_columna": "ENERO 2001",
#     "reajuste_porcentaje": "8.39%",
#     "interes_afiliado_porcentaje": "1696.02%",
#     "recargo_beneficio_afiliado_porcentaje": "339.20%"
#   }
# ]
# ```
#
#
# Procesando sección de tabla horizontal 2 (Y: 1616-3298) de page_5.png
#     Procesando segmento vertical 1 de la sección 2 (Global ID: 3): X[0-1463], Y[1616-3298]
#       Segmento original guardado en: segmentos_guardados/page_5_tabla2_seg1_orig.png
#       Preprocesamiento desactivado para este segmento.
#
# Procesando imagen: segmentos_guardados/page_5_tabla2_seg1_orig.png con Gemini, prompt v_few_shot (con énfasis anti-omisión)...
# Respuesta cruda de Gemini para segmentos_guardados/page_5_tabla2_seg1_orig.png:
# ```json
# [
#   {
#     "mes_año_columna": "FEBRERO 2001",
#     "reajuste_porcentaje": "8.39%",
#     "interes_afiliado_porcentaje": "1666.50%",
#     "recargo_beneficio_afiliado_porcentaje": "333.30%"
#   },
#   {
#     "mes_año_columna": "MARZO 2001",
#     "reajuste_porcentaje": "8.39%",
#     "interes_afiliado_porcentaje": "1638.52%",
#     "recargo_beneficio_afiliado_porcentaje": "327.70%"
#   }
# ]
# ```
#
#     Procesando segmento vertical 2 de la sección 2 (Global ID: 4): X[1087-2550], Y[1616-3298]
#       Segmento original guardado en: segmentos_guardados/page_5_tabla2_seg2_orig.png
#       Preprocesamiento desactivado para este segmento.
#
# Procesando imagen: segmentos_guardados/page_5_tabla2_seg2_orig.png con Gemini, prompt v_few_shot (con énfasis anti-omisión)...
# Respuesta cruda de Gemini para segmentos_guardados/page_5_tabla2_seg2_orig.png:
# ```json
# [
#   {
#     "mes_año_columna": "MARZO 2001",
#     "reajuste_porcentaje": "8.39%",
#     "interes_afiliado_porcentaje": "1577.99%",
#     "recargo_beneficio_afiliado_porcentaje": "321.07%"
#   },
#   {
#     "mes_año_columna": "ABRIL 2001",
#     "reajuste_porcentaje": "8.39%",
#     "interes_afiliado_porcentaje": "1551.10%",
#     "recargo_beneficio_afiliado_porcentaje": "315.60%"
#   },
#   {
#     "mes_año_columna": "MAYO 2001",
#     "reajuste_porcentaje": "8.39%",
#     "interes_afiliado_porcentaje": "1551.10%",
#     "recargo_beneficio_afiliado_porcentaje": "310.22%"
#   }
# ]
# ```
#
# --- Fin del procesamiento para la página: /content/drive/MyDrive/DEUDA_PREVISIONAL/PDFS/2017/page_5.png ---
#
# --- Procesando página completa: /content/drive/MyDrive/DEUDA_PREVISIONAL/PDFS/2017/page_6.png ---
# Usando num_segmentos_verticales_por_tabla=2, overlap_px=188
# Configuración de Preprocesamiento: General=False, Upscaling=False, Gris=True, CLAHE=True, Thresholding=False, Denoising=False, Nitidez=False
#
# Procesando sección de tabla horizontal 1 (Y: 0-1616) de page_6.png
#     Procesando segmento vertical 1 de la sección 1 (Global ID: 1): X[0-1463], Y[0-1616]
#       Segmento original guardado en: segmentos_guardados/page_6_tabla1_seg1_orig.png
#       Preprocesamiento desactivado para este segmento.
#
# Procesando imagen: segmentos_guardados/page_6_tabla1_seg1_orig.png con Gemini, prompt v_few_shot (con énfasis anti-omisión)...
# Respuesta cruda de Gemini para segmentos_guardados/page_6_tabla1_seg1_orig.png:
# ```json
# [
#   {
#     "mes_año_columna": "JUNIO 2001",
#     "reajuste_porcentaje": "6.58%",
#     "interes_afiliado_porcentaje": "1577.90%",
#     "recargo_beneficio_afiliado_porcentaje": "315.58%"
#   },
#   {
#     "mes_año_columna": "JULIO 2001",
#     "reajuste_porcentaje": "6.58%",
#     "interes_afiliado_porcentaje": "1552.43%",
#     "recargo_beneficio_afiliado_porcentaje": "310.49%"
#   },
#   {
#     "mes_año_columna": "AGOSTO 2001",
#     "reajuste_porcentaje": "6.58%",
#     "interes_afiliado_porcentaje": "1527.22%",
#     "recargo_beneficio_afiliado_porcentaje": "305.44%"
#   }
# ]
# ```
#
#     Procesando segmento vertical 2 de la sección 1 (Global ID: 2): X[1087-2550], Y[0-1616]
#       Segmento original guardado en: segmentos_guardados/page_6_tabla1_seg2_orig.png
#       Preprocesamiento desactivado para este segmento.
#
# Procesando imagen: segmentos_guardados/page_6_tabla1_seg2_orig.png con Gemini, prompt v_few_shot (con énfasis anti-omisión)...
# Respuesta cruda de Gemini para segmentos_guardados/page_6_tabla1_seg2_orig.png:
# ```json
# [
#   {
#     "mes_año_columna": "AGOSTO 2001",
#     "reajuste_porcentaje": "6.58%",
#     "interes_afiliado_porcentaje": "1530.37%",
#     "recargo_beneficio_afiliado_porcentaje": "306.07%"
#   },
#   {
#     "mes_año_columna": "SEPTIEMBRE 2001",
#     "reajuste_porcentaje": "6.58%",
#     "interes_afiliado_porcentaje": "1517.12%",
#     "recargo_beneficio_afiliado_porcentaje": "303.42%"
#   },
#   {
#     "mes_año_columna": "OCTUBRE 2001",
#     "reajuste_porcentaje": "6.58%",
#     "interes_afiliado_porcentaje": "1503.90%",
#     "recargo_beneficio_afiliado_porcentaje": "300.78%"
#   }
# ]
# ```
#
#
# Procesando sección de tabla horizontal 2 (Y: 1616-3298) de page_6.png
#     Procesando segmento vertical 1 de la sección 2 (Global ID: 3): X[0-1463], Y[1616-3298]
#       Segmento original guardado en: segmentos_guardados/page_6_tabla2_seg1_orig.png
#       Preprocesamiento desactivado para este segmento.
#
# Procesando imagen: segmentos_guardados/page_6_tabla2_seg1_orig.png con Gemini, prompt v_few_shot (con énfasis anti-omisión)...
# Respuesta cruda de Gemini para segmentos_guardados/page_6_tabla2_seg1_orig.png:
# ```json
# [
#   {
#     "mes_año_columna": "NOVIEMBRE 2001",
#     "reajuste_porcentaje": "6.58%",
#     "interes_afiliado_porcentaje": "1485.47%",
#     "recargo_beneficio_afiliado_porcentaje": "297.09%"
#   },
#   {
#     "mes_año_columna": "DICIEMBRE 2001",
#     "reajuste_porcentaje": "6.58%",
#     "interes_afiliado_porcentaje": "1464.71%",
#     "recargo_beneficio_afiliado_porcentaje": "292.84%"
#   },
#   {
#     "mes_año_columna": "ENERO 2002",
#     "reajuste_porcentaje": "6.58%",
#     "interes_afiliado_porcentaje": "1441.72%",
#     "recargo_beneficio_afiliado_porcentaje": "288.34%"
#   }
# ]
# ```
#
#     Procesando segmento vertical 2 de la sección 2 (Global ID: 4): X[1087-2550], Y[1616-3298]
#       Segmento original guardado en: segmentos_guardados/page_6_tabla2_seg2_orig.png
#       Preprocesamiento desactivado para este segmento.
#
# Procesando imagen: segmentos_guardados/page_6_tabla2_seg2_orig.png con Gemini, prompt v_few_shot (con énfasis anti-omisión)...
# Respuesta cruda de Gemini para segmentos_guardados/page_6_tabla2_seg2_orig.png:
# ```json
# [
#   {
#     "mes_año_columna": "ENERO 2002",
#     "reajuste_porcentaje": "6.58%",
#     "interes_afiliado_porcentaje": "1441.72%",
#     "recargo_beneficio_afiliado_porcentaje": "288.34%"
#   },
#   {
#     "mes_año_columna": "FEBRERO 2002",
#     "reajuste_porcentaje": "6.58%",
#     "interes_afiliado_porcentaje": "1423.86%",
#     "recargo_beneficio_afiliado_porcentaje": "284.77%"
#   },
#   {
#     "mes_año_columna": "MARZO 2002",
#     "reajuste_porcentaje": "6.58%",
#     "interes_afiliado_porcentaje": "1404.35%",
#     "recargo_beneficio_afiliado_porcentaje": "280.87%"
#   }
# ]
# ```
#
# --- Fin del procesamiento para la página: /content/drive/MyDrive/DEUDA_PREVISIONAL/PDFS/2017/page_6.png ---
#
# --- Procesando página completa: /content/drive/MyDrive/DEUDA_PREVISIONAL/PDFS/2017/page_7.png ---
# Usando num_segmentos_verticales_por_tabla=2, overlap_px=188
# Configuración de Preprocesamiento: General=False, Upscaling=False, Gris=True, CLAHE=True, Thresholding=False, Denoising=False, Nitidez=False
#
# Procesando sección de tabla horizontal 1 (Y: 0-1616) de page_7.png
#     Procesando segmento vertical 1 de la sección 1 (Global ID: 1): X[0-1463], Y[0-1616]
#       Segmento original guardado en: segmentos_guardados/page_7_tabla1_seg1_orig.png
#       Preprocesamiento desactivado para este segmento.
#
# Procesando imagen: segmentos_guardados/page_7_tabla1_seg1_orig.png con Gemini, prompt v_few_shot (con énfasis anti-omisión)...
# Respuesta cruda de Gemini para segmentos_guardados/page_7_tabla1_seg1_orig.png:
# ```json
# [
#   {
#     "mes_año_columna": "ABRIL 2002",
#     "reajuste_porcentaje": "6.58%",
#     "interes_afiliado_porcentaje": "1385.96%",
#     "recargo_beneficio_afiliado_porcentaje": "277.19%"
#   },
#   {
#     "mes_año_columna": "MAYO 2002",
#     "reajuste_porcentaje": "6.58%",
#     "interes_afiliado_porcentaje": "1367.44%",
#     "recargo_beneficio_afiliado_porcentaje": "273.49%"
#   }
# ]
# ```
#
#     Procesando segmento vertical 2 de la sección 1 (Global ID: 2): X[1087-2550], Y[0-1616]
#       Segmento original guardado en: segmentos_guardados/page_7_tabla1_seg2_orig.png
#       Preprocesamiento desactivado para este segmento.
#
# Procesando imagen: segmentos_guardados/page_7_tabla1_seg2_orig.png con Gemini, prompt v_few_shot (con énfasis anti-omisión)...
# Respuesta cruda de Gemini para segmentos_guardados/page_7_tabla1_seg2_orig.png:
# ```json
# [
#   {
#     "mes_año_columna": "MAYO 2002",
#     "reajuste_porcentaje": "6.58%",
#     "interes_afiliado_porcentaje": "1333.94%",
#     "recargo_beneficio_afiliado_porcentaje": "266.79%"
#   },
#   {
#     "mes_año_columna": "JUNIO 2002",
#     "reajuste_porcentaje": "6.58%",
#     "interes_afiliado_porcentaje": "1333.03%",
#     "recargo_beneficio_afiliado_porcentaje": "266.61%"
#   },
#   {
#     "mes_año_columna": "JULIO 2002",
#     "reajuste_porcentaje": "6.58%",
#     "interes_afiliado_porcentaje": "1331.21%",
#     "recargo_beneficio_afiliado_porcentaje": "266.24%"
#   }
# ]
# ```
#
#
# Procesando sección de tabla horizontal 2 (Y: 1616-3298) de page_7.png
#     Procesando segmento vertical 1 de la sección 2 (Global ID: 3): X[0-1463], Y[1616-3298]
#       Segmento original guardado en: segmentos_guardados/page_7_tabla2_seg1_orig.png
#       Preprocesamiento desactivado para este segmento.
#
# Procesando imagen: segmentos_guardados/page_7_tabla2_seg1_orig.png con Gemini, prompt v_few_shot (con énfasis anti-omisión)...
# Respuesta cruda de Gemini para segmentos_guardados/page_7_tabla2_seg1_orig.png:
# No puedo procesar la imagen que has proporcionado porque es completamente blanca. No hay datos financieros presentes para poder extraer la información solicitada.  Por lo tanto, la respuesta es una lista vacía:
#
# ```json
# []
# ```
#
#       No se extrajeron datos del segmento segmentos_guardados/page_7_tabla2_seg1_orig.png.
#     Procesando segmento vertical 2 de la sección 2 (Global ID: 4): X[1087-2550], Y[1616-3298]
#       Segmento original guardado en: segmentos_guardados/page_7_tabla2_seg2_orig.png
#       Preprocesamiento desactivado para este segmento.
#
# Procesando imagen: segmentos_guardados/page_7_tabla2_seg2_orig.png con Gemini, prompt v_few_shot (con énfasis anti-omisión)...
# Respuesta cruda de Gemini para segmentos_guardados/page_7_tabla2_seg2_orig.png:
# No puedo procesar la imagen que has proporcionado porque es una imagen en blanco.  Para poder extraer la información que solicitas, necesito una imagen que contenga las tablas de datos financieras.  Por favor, proporciona una imagen con datos.
#
# Advertencia: La respuesta de Gemini para segmentos_guardados/page_7_tabla2_seg2_orig.png no parece ser un bloque JSON estándar. Se intentará parsear directamente.
# Error al decodificar JSON de la respuesta de Gemini para segmentos_guardados/page_7_tabla2_seg2_orig.png: Expecting value: line 1 column 1 (char 0)
# String que causó el error (json_str):
# >>>
# No puedo procesar la imagen que has proporcionado porque es una imagen en blanco.  Para poder extraer la información que solicitas, necesito una imagen que contenga las tablas de datos financieras.  Por favor, proporciona una imagen con datos.
#
# <<<
# Respuesta original completa (text_response):
# >>>
# No puedo procesar la imagen que has proporcionado porque es una imagen en blanco.  Para poder extraer la información que solicitas, necesito una imagen que contenga las tablas de datos financieras.  Por favor, proporciona una imagen con datos.
#
# <<<
#       No se extrajeron datos del segmento segmentos_guardados/page_7_tabla2_seg2_orig.png.
# --- Fin del procesamiento para la página: /content/drive/MyDrive/DEUDA_PREVISIONAL/PDFS/2017/page_7.png ---
#
# --- Procesando página completa: /content/drive/MyDrive/DEUDA_PREVISIONAL/PDFS/2017/page_8.png ---
# Usando num_segmentos_verticales_por_tabla=2, overlap_px=188
# Configuración de Preprocesamiento: General=False, Upscaling=False, Gris=True, CLAHE=True, Thresholding=False, Denoising=False, Nitidez=False
#
# Procesando sección de tabla horizontal 1 (Y: 0-1617) de page_8.png
#     Procesando segmento vertical 1 de la sección 1 (Global ID: 1): X[0-1463], Y[0-1617]
#       Segmento original guardado en: segmentos_guardados/page_8_tabla1_seg1_orig.png
#       Preprocesamiento desactivado para este segmento.
#
# Procesando imagen: segmentos_guardados/page_8_tabla1_seg1_orig.png con Gemini, prompt v_few_shot (con énfasis anti-omisión)...
# Respuesta cruda de Gemini para segmentos_guardados/page_8_tabla1_seg1_orig.png:
# ```json
# [
#   {
#     "mes_año_columna": "AGOSTO 2002",
#     "reajuste_porcentaje": "8.39%",
#     "interes_afiliado_porcentaje": "1372.19%",
#     "recargo_beneficio_afiliado_porcentaje": "274.44%"
#   },
#   {
#     "mes_año_columna": "SEPTIEMBRE 2002",
#     "reajuste_porcentaje": "8.39%",
#     "interes_afiliado_porcentaje": "1358.51%",
#     "recargo_beneficio_afiliado_porcentaje": "271.70%"
#   }
# ]
# ```
#
#     Procesando segmento vertical 2 de la sección 1 (Global ID: 2): X[1087-2550], Y[0-1617]
#       Segmento original guardado en: segmentos_guardados/page_8_tabla1_seg2_orig.png
#       Preprocesamiento desactivado para este segmento.
#
# Procesando imagen: segmentos_guardados/page_8_tabla1_seg2_orig.png con Gemini, prompt v_few_shot (con énfasis anti-omisión)...
# Respuesta cruda de Gemini para segmentos_guardados/page_8_tabla1_seg2_orig.png:
# ```json
# [
#   {
#     "mes_año_columna": "SEPTIEMBRE 2002",
#     "reajuste_porcentaje": "8.39%",
#     "interes_afiliado_porcentaje": "1333.72%",
#     "recargo_beneficio_afiliado_porcentaje": "266.74%"
#   },
#   {
#     "mes_año_columna": "OCTUBRE 2002",
#     "reajuste_porcentaje": "8.07%",
#     "interes_afiliado_porcentaje": "1330.14%",
#     "recargo_beneficio_afiliado_porcentaje": "266.03%"
#   },
#   {
#     "mes_año_columna": "NOVIEMBRE 2002",
#     "reajuste_porcentaje": "7.22%",
#     "interes_afiliado_porcentaje": "1342.98%",
#     "recargo_beneficio_afiliado_porcentaje": "268.60%"
#   }
# ]
# ```
#
#
# Procesando sección de tabla horizontal 2 (Y: 1617-3301) de page_8.png
#     Procesando segmento vertical 1 de la sección 2 (Global ID: 3): X[0-1463], Y[1617-3301]
#       Segmento original guardado en: segmentos_guardados/page_8_tabla2_seg1_orig.png
#       Preprocesamiento desactivado para este segmento.
#
# Procesando imagen: segmentos_guardados/page_8_tabla2_seg1_orig.png con Gemini, prompt v_few_shot (con énfasis anti-omisión)...
# Respuesta cruda de Gemini para segmentos_guardados/page_8_tabla2_seg1_orig.png:
# ```json
# [
#   {
#     "mes_año_columna": "DICIEMBRE 2002",
#     "reajuste_porcentaje": "6.58%",
#     "interes_afiliado_porcentaje": "1336.98%",
#     "recargo_beneficio_afiliado_porcentaje": "267.40%"
#   },
#   {
#     "mes_año_columna": "ENERO 2003",
#     "reajuste_porcentaje": "6.58%",
#     "interes_afiliado_porcentaje": "1323.87%",
#     "recargo_beneficio_afiliado_porcentaje": "264.77%"
#   }
# ]
# ```
#
#     Procesando segmento vertical 2 de la sección 2 (Global ID: 4): X[1087-2550], Y[1617-3301]
#       Segmento original guardado en: segmentos_guardados/page_8_tabla2_seg2_orig.png
#       Preprocesamiento desactivado para este segmento.
#
# Procesando imagen: segmentos_guardados/page_8_tabla2_seg2_orig.png con Gemini, prompt v_few_shot (con énfasis anti-omisión)...
# Respuesta cruda de Gemini para segmentos_guardados/page_8_tabla2_seg2_orig.png:
# ```json
# [
#   {
#     "mes_año_columna": "ENERO 2003",
#     "reajuste_porcentaje": "6.58%",
#     "interes_afiliado_porcentaje": "1285.74%",
#     "recargo_beneficio_afiliado_porcentaje": "259.34%"
#   },
#   {
#     "mes_año_columna": "FEBRERO 2003",
#     "reajuste_porcentaje": "6.58%",
#     "interes_afiliado_porcentaje": "1274.95%",
#     "recargo_beneficio_afiliado_porcentaje": "257.15%"
#   },
#   {
#     "mes_año_columna": "MARZO 2003",
#     "reajuste_porcentaje": "6.30%",
#     "interes_afiliado_porcentaje": "1274.95%",
#     "recargo_beneficio_afiliado_porcentaje": "254.99%"
#   }
# ]
# ```
# --- Fin del procesamiento para la página: /content/drive/MyDrive/DEUDA_PREVISIONAL/PDFS/2017/page_8.png ---
#
# --- Procesando página completa: /content/drive/MyDrive/DEUDA_PREVISIONAL/PDFS/2017/page_9.png ---
# Usando num_segmentos_verticales_por_tabla=2, overlap_px=188
# Configuración de Preprocesamiento: General=False, Upscaling=False, Gris=True, CLAHE=True, Thresholding=False, Denoising=False, Nitidez=False
#
# Procesando sección de tabla horizontal 1 (Y: 0-1617) de page_9.png
#     Procesando segmento vertical 1 de la sección 1 (Global ID: 1): X[0-1463], Y[0-1617]
#       Segmento original guardado en: segmentos_guardados/page_9_tabla1_seg1_orig.png
#       Preprocesamiento desactivado para este segmento.
#
# Procesando imagen: segmentos_guardados/page_9_tabla1_seg1_orig.png con Gemini, prompt v_few_shot (con énfasis anti-omisión)...
# Respuesta cruda de Gemini para segmentos_guardados/page_9_tabla1_seg1_orig.png:
# ```json
# [
#   {
#     "mes_año_columna": "ABRIL 2003",
#     "reajuste_porcentaje": "5.24%",
#     "interes_afiliado_porcentaje": "1295.46%",
#     "recargo_beneficio_afiliado_porcentaje": "259.09%"
#   },
#   {
#     "mes_año_columna": "MAYO 2003",
#     "reajuste_porcentaje": "4.47%",
#     "interes_afiliado_porcentaje": "1287.56%",
#     "recargo_beneficio_afiliado_porcentaje": "257.51%"
#   },
#   {
#     "mes_año_columna": "JUNIO 2003",
#     "reajuste_porcentaje": null,
#     "interes_afiliado_porcentaje": "1275.37%",
#     "recargo_beneficio_afiliado_porcentaje": null
#   }
# ]
# ```
#     Procesando segmento vertical 2 de la sección 1 (Global ID: 2): X[1087-2550], Y[0-1617]
#       Segmento original guardado en: segmentos_guardados/page_9_tabla1_seg2_orig.png
#       Preprocesamiento desactivado para este segmento.
#
# Procesando imagen: segmentos_guardados/page_9_tabla1_seg2_orig.png con Gemini, prompt v_few_shot (con énfasis anti-omisión)...
# Respuesta cruda de Gemini para segmentos_guardados/page_9_tabla1_seg2_orig.png:
# ```json
# [
#   {
#     "mes_año_columna": "MAYO 2003",
#     "reajuste_porcentaje": "4.47%",
#     "interes_afiliado_porcentaje": "1249.14%",
#     "recargo_beneficio_afiliado_porcentaje": "249.83%"
#   },
#   {
#     "mes_año_columna": "JUNIO 2003",
#     "reajuste_porcentaje": "4.47%",
#     "interes_afiliado_porcentaje": "1236.60%",
#     "recargo_beneficio_afiliado_porcentaje": "247.32%"
#   },
#   {
#     "mes_año_columna": "JULIO 2003",
#     "reajuste_porcentaje": "4.47%",
#     "interes_afiliado_porcentaje": "1236.60%",
#     "recargo_beneficio_afiliado_porcentaje": "247.32%"
#   }
# ]
# ```
#
#
# Procesando sección de tabla horizontal 2 (Y: 1617-3301) de page_9.png
#     Procesando segmento vertical 1 de la sección 2 (Global ID: 3): X[0-1463], Y[1617-3301]
#       Segmento original guardado en: segmentos_guardados/page_9_tabla2_seg1_orig.png
#       Preprocesamiento desactivado para este segmento.
#
# Procesando imagen: segmentos_guardados/page_9_tabla2_seg1_orig.png con Gemini, prompt v_few_shot (con énfasis anti-omisión)...
# Respuesta cruda de Gemini para segmentos_guardados/page_9_tabla2_seg1_orig.png:
# ```json
# [
#   {
#     "mes_año_columna": "AGOSTO 2003",
#     "reajuste_porcentaje": "4.47%",
#     "interes_afiliado_porcentaje": "1250.87%",
#     "recargo_beneficio_afiliado_porcentaje": "250.17%"
#   },
#   {
#     "mes_año_columna": "SEPTIEMBRE 2003",
#     "reajuste_porcentaje": "4.47%",
#     "interes_afiliado_porcentaje": "1237.48%",
#     "recargo_beneficio_afiliado_porcentaje": "247.50%"
#   }
# ]
# ```
#
#     Procesando segmento vertical 2 de la sección 2 (Global ID: 4): X[1087-2550], Y[1617-3301]
#       Segmento original guardado en: segmentos_guardados/page_9_tabla2_seg2_orig.png
#       Preprocesamiento desactivado para este segmento.
#
# Procesando imagen: segmentos_guardados/page_9_tabla2_seg2_orig.png con Gemini, prompt v_few_shot (con énfasis anti-omisión)...
# Respuesta cruda de Gemini para segmentos_guardados/page_9_tabla2_seg2_orig.png:
# ```json
# [
#   {
#     "mes_año_columna": "SEPTIEMBRE 2003",
#     "reajuste_porcentaje": "4.47%",
#     "interes_afiliado_porcentaje": "1193.95%",
#     "recargo_beneficio_afiliado_porcentaje": "238.79%"
#   },
#   {
#     "mes_año_columna": "OCTUBRE 2003",
#     "reajuste_porcentaje": "4.47%",
#     "interes_afiliado_porcentaje": "1206.58%",
#     "recargo_beneficio_afiliado_porcentaje": "241.32%"
#   },
#   {
#     "mes_año_columna": "NOVIEMBRE 2003",
#     "reajuste_porcentaje": "4.47%",
#     "interes_afiliado_porcentaje": "1211.45%",
#     "recargo_beneficio_afiliado_porcentaje": "242.29%"
#   }
# ]
# ```
#
# --- Fin del procesamiento para la página: /content/drive/MyDrive/DEUDA_PREVISIONAL/PDFS/2017/page_9.png ---
#
# --- Procesando página completa: /content/drive/MyDrive/DEUDA_PREVISIONAL/PDFS/2017/page_10.png ---
# Usando num_segmentos_verticales_por_tabla=2, overlap_px=188
# Configuración de Preprocesamiento: General=False, Upscaling=False, Gris=True, CLAHE=True, Thresholding=False, Denoising=False, Nitidez=False
#
# Procesando sección de tabla horizontal 1 (Y: 0-1617) de page_10.png
#     Procesando segmento vertical 1 de la sección 1 (Global ID: 1): X[0-1463], Y[0-1617]
#       Segmento original guardado en: segmentos_guardados/page_10_tabla1_seg1_orig.png
#       Preprocesamiento desactivado para este segmento.
#
# Procesando imagen: segmentos_guardados/page_10_tabla1_seg1_orig.png con Gemini, prompt v_few_shot (con énfasis anti-omisión)...
# Respuesta cruda de Gemini para segmentos_guardados/page_10_tabla1_seg1_orig.png:
# ```json
# [
#   {
#     "mes_año_columna": "DICIEMBRE 2003",
#     "reajuste_porcentaje": "4.47%",
#     "interes_afiliado_porcentaje": "1195.91%",
#     "recargo_beneficio_afiliado_porcentaje": "239.18%"
#   },
#   {
#     "mes_año_columna": "ENERO 2004",
#     "reajuste_porcentaje": "4.47%",
#     "interes_afiliado_porcentaje": "1182.87%",
#     "recargo_beneficio_afiliado_porcentaje": "236.57%"
#   }
# ]
# ```
#
#     Procesando segmento vertical 2 de la sección 1 (Global ID: 2): X[1087-2550], Y[0-1617]
#       Segmento original guardado en: segmentos_guardados/page_10_tabla1_seg2_orig.png
#       Preprocesamiento desactivado para este segmento.
#
# Procesando imagen: segmentos_guardados/page_10_tabla1_seg2_orig.png con Gemini, prompt v_few_shot (con énfasis anti-omisión)...
# Respuesta cruda de Gemini para segmentos_guardados/page_10_tabla1_seg2_orig.png:
# ```json
# [
#   {
#     "mes_año_columna": "ENERO 2004",
#     "reajuste_porcentaje": "4.47%",
#     "interes_afiliado_porcentaje": "1145.65%",
#     "recargo_beneficio_afiliado_porcentaje": "231.68%"
#   },
#   {
#     "mes_año_columna": "FEBRERO 2004",
#     "reajuste_porcentaje": "4.47%",
#     "interes_afiliado_porcentaje": "1146.45%",
#     "recargo_beneficio_afiliado_porcentaje": "229.13%"
#   },
#   {
#     "mes_año_columna": "MARZO 2004",
#     "reajuste_porcentaje": "4.47%",
#     "interes_afiliado_porcentaje": "1131.33%",
#     "recargo_beneficio_afiliado_porcentaje": "226.27%"
#   }
# ]
# ```
#
# Procesando sección de tabla horizontal 2 (Y: 1617-3301) de page_10.png
#     Procesando segmento vertical 1 de la sección 2 (Global ID: 3): X[0-1463], Y[1617-3301]
#       Segmento original guardado en: segmentos_guardados/page_10_tabla2_seg1_orig.png
#       Preprocesamiento desactivado para este segmento.
#
# Procesando imagen: segmentos_guardados/page_10_tabla2_seg1_orig.png con Gemini, prompt v_few_shot (con énfasis anti-omisión)...
# Respuesta cruda de Gemini para segmentos_guardados/page_10_tabla2_seg1_orig.png:
# ```json
# [
#   {
#     "mes_año_columna": "ABRIL 2004",
#     "reajuste_porcentaje": "4.47%",
#     "interes_afiliado_porcentaje": "1142.69%",
#     "recargo_beneficio_afiliado_porcentaje": "228.54%"
#   },
#   {
#     "mes_año_columna": "MAYO 2004",
#     "reajuste_porcentaje": "4.47%",
#     "interes_afiliado_porcentaje": "1127.55%",
#     "recargo_beneficio_afiliado_porcentaje": "225.51%"
#   }
# ]
# ```
#
#     Procesando segmento vertical 2 de la sección 2 (Global ID: 4): X[1087-2550], Y[1617-3301]
#       Segmento original guardado en: segmentos_guardados/page_10_tabla2_seg2_orig.png
#       Preprocesamiento desactivado para este segmento.
#
# Procesando imagen: segmentos_guardados/page_10_tabla2_seg2_orig.png con Gemini, prompt v_few_shot (con énfasis anti-omisión)...
# Respuesta cruda de Gemini para segmentos_guardados/page_10_tabla2_seg2_orig.png:
# ```json
# [
#   {
#     "mes_año_columna": "MAYO 2004",
#     "reajuste_porcentaje": "4.47%",
#     "interes_afiliado_porcentaje": "1090.74%",
#     "recargo_beneficio_afiliado_porcentaje": "218.15%"
#   },
#   {
#     "mes_año_columna": "JUNIO 2004",
#     "reajuste_porcentaje": "4.47%",
#     "interes_afiliado_porcentaje": "1080.49%",
#     "recargo_beneficio_afiliado_porcentaje": "216.10%"
#   },
#   {
#     "mes_año_columna": "JULIO 2004",
#     "reajuste_porcentaje": "4.47%",
#     "interes_afiliado_porcentaje": "1081.26%",
#     "recargo_beneficio_afiliado_porcentaje": "216.25%"
#   }
# ]
# ```
#
# --- Fin del procesamiento para la página: /content/drive/MyDrive/DEUDA_PREVISIONAL/PDFS/2017/page_10.png ---
#
# --- Procesando página completa: /content/drive/MyDrive/DEUDA_PREVISIONAL/PDFS/2017/page_11.png ---
# Usando num_segmentos_verticales_por_tabla=2, overlap_px=188
# Configuración de Preprocesamiento: General=False, Upscaling=False, Gris=True, CLAHE=True, Thresholding=False, Denoising=False, Nitidez=False
#
# Procesando sección de tabla horizontal 1 (Y: 0-1617) de page_11.png
#     Procesando segmento vertical 1 de la sección 1 (Global ID: 1): X[0-1463], Y[0-1617]
#       Segmento original guardado en: segmentos_guardados/page_11_tabla1_seg1_orig.png
#       Preprocesamiento desactivado para este segmento.
#
# Procesando imagen: segmentos_guardados/page_11_tabla1_seg1_orig.png con Gemini, prompt v_few_shot (con énfasis anti-omisión)...
# Respuesta cruda de Gemini para segmentos_guardados/page_11_tabla1_seg1_orig.png:
# ```json
# [
#   {
#     "mes_año_columna": "AGOSTO 2004",
#     "reajuste_porcentaje": "4.47%",
#     "interes_afiliado_porcentaje": "1091.73%",
#     "recargo_beneficio_afiliado_porcentaje": "218.35%"
#   },
#   {
#     "mes_año_columna": "SEPTIEMBRE 2004",
#     "reajuste_porcentaje": "4.47%",
#     "interes_afiliado_porcentaje": "1080.02%",
#     "recargo_beneficio_afiliado_porcentaje": "216.00%"
#   }
# ]
# ```
#
#     Procesando segmento vertical 2 de la sección 1 (Global ID: 2): X[1087-2550], Y[0-1617]
#       Segmento original guardado en: segmentos_guardados/page_11_tabla1_seg2_orig.png
#       Preprocesamiento desactivado para este segmento.
#
# Procesando imagen: segmentos_guardados/page_11_tabla1_seg2_orig.png con Gemini, prompt v_few_shot (con énfasis anti-omisión)...
# Respuesta cruda de Gemini para segmentos_guardados/page_11_tabla1_seg2_orig.png:
# ```json
# [
#   {
#     "mes_año_columna": "TIEMBRE 2004",
#     "reajuste_porcentaje": "4.47%",
#     "interes_afiliado_porcentaje": "1069.53%",
#     "recargo_beneficio_afiliado_porcentaje": null
#   },
#   {
#     "mes_año_columna": "OCTUBRE 2004",
#     "reajuste_porcentaje": "4.47%",
#     "interes_afiliado_porcentaje": "1066.56%",
#     "recargo_beneficio_afiliado_porcentaje": null
#   },
#   {
#     "mes_año_columna": "NOVIEMBRE 2004",
#     "reajuste_porcentaje": "4.47%",
#     "interes_afiliado_porcentaje": "1063.59%",
#     "recargo_beneficio_afiliado_porcentaje": null
#   }
# ]
# ```
#
#
# Procesando sección de tabla horizontal 2 (Y: 1617-3301) de page_11.png
#     Procesando segmento vertical 1 de la sección 2 (Global ID: 3): X[0-1463], Y[1617-3301]
#       Segmento original guardado en: segmentos_guardados/page_11_tabla2_seg1_orig.png
#       Preprocesamiento desactivado para este segmento.
#
# Procesando imagen: segmentos_guardados/page_11_tabla2_seg1_orig.png con Gemini, prompt v_few_shot (con énfasis anti-omisión)...
# ...
# 44         MAYO 2004               4.47%                    1127.55%                               225.51%
# 45        JUNIO 2004               4.47%                    1080.49%                               216.10%
# 46       AGOSTO 2004               4.47%                    1091.73%                               218.35%
# 47   SEPTIEMBRE 2004               4.47%                    1080.02%                               216.00%
# 48      OCTUBRE 2004               4.47%                    1066.56%                                  None
# 49    NOVIEMBRE 2004               4.47%                    1063.59%                                  None
# 50    DICIEMBRE 2004               4.47%                    1046.39%                               209.28%
# 51        ENERO 2005               4.47%                    1035.28%                               207.06%
# 52       AGOSTO 2005               3.54%                     960.37%                               192.07%
# 53   SEPTIEMBRE 2005               3.54%                     947.66%                               189.53%
# 54      OCTUBRE 2005               3.20%                     920.28%                               184.06%
# 55        ENERO 2006               2.52%                     906.25%                               181.25%
# 56      FEBRERO 2006               2.52%                     894.94%                               178.99%
# 57        MARZO 2006               1.00%                     891.90%                               445.95%
# 58        ABRIL 2006               1.00%                     879.23%                               439.62%
# 59         MAYO 2006               1.00%                     849.97%                               424.99%
# 60        JUNIO 2006               1.00%                     846.57%                               423.28%
# 61        JULIO 2006               1.00%                     826.81%                               413.41%
# 62       AGOSTO 2006               1.00%                     807.70%                               403.85%
# 63   SEPTIEMBRE 2006               1.00%                     808.28%                               404.14%
# 64      OCTUBRE 2006               1.00%                     808.86%                               404.43%
# 65    NOVIEMBRE 2006               1.00%                     789.79%                               394.90%
# 66    DICIEMBRE 2006               1.00%                     778.22%                               389.11%
# 67        ENERO 2007               1.00%                     753.40%                               376.70%
# 68      FEBRERO 2007               1.00%                        None                                  None
# 69        MARZO 2007               1.00%                     741.46%                               370.73%
# 70        ABRIL 2007               1.00%                     729.91%                               364.96%
# 71         MAYO 2007               1.00%                     702.83%                               351.41%
# 72        JUNIO 2007               1.00%                     690.79%                               345.40%
# 73        JULIO 2007               1.00%                     680.33%                               340.16%
# 74       AGOSTO 2007               1.00%                     663.53%                               331.76%
# 75   SEPTIEMBRE 2007               1.00%                     653.08%                               326.54%
# 76      OCTUBRE 2007               1.00%                     638.77%                               319.39%
# 77    NOVIEMBRE 2007               1.00%                     632.32%                               316.16%
# 78    DICIEMBRE 2007               1.00%                     617.90%                               308.95%
# 79        ENERO 2008               1.00%                     597.86%                                  None
# 80      FEBRERO 2008               1.00%                     597.86%                                  None
# 81        MARZO 2008               1.00%                     588.60%                               294.30%
# 82        ABRIL 2008               1.00%                     578.92%                               289.46%
# 83         MAYO 2008               1.00%                     570.42%                               285.21%
# 84        JUNIO 2008               1.00%                     561.16%                               280.58%
# 85        JULIO 2008               1.00%                     551.28%                               275.64%
# 86       AGOSTO 2008               1.00%                     542.46%                               271.23%
# 87   SEPTIEMBRE 2008               1.00%                     528.98%                               264.49%
# 88      OCTUBRE 2008               1.00%                     529.38%                               264.69%
# 89    NOVIEMBRE 2008               1.00%                     515.18%                               257.59%
# 90    DICIEMBRE 2008               1.00%                     504.98%                               252.49%
# 91    NOVILMBRE 2009               0.00%                     417.42%                               208.71%
# 92        ENERO 2009               2.00%                     475.09%                               237.55%
# 93        MARZO 2009               1.00%                     465.22%                                  None
# 94        ABRIL 2009               1.00%                     465.87%                                  None
# 95         MAYO 2009               1.00%                     454.92%                               227.46%
# 96        JULIO 2009               1.00%                     439.92%                               219.96%
# 97       AGOSTO 2009               1.00%                     432.41%                               216.20%
# 98   SEPTIEMBRE 2009               1.00%                     419.44%                               209.72%
# 99      OCTUBRE 2009               0.67%                     415.27%                               207.63%
# 100   DICIEMBRE 2009               0.00%                     407.87%                               203.93%
# 101       ENERO 2010               0.00%                     390.82%                                  None
# 102     FEBRERO 2010               0.00%                     382.87%                                  None
# 103       MARZO 2010               0.00%                     378.24%                               189.12%
# 104       ABRIL 2010               0.00%                     368.95%                               184.47%
# 105        MAYO 2010               0.00%                     340.98%                               170.49%
# 106       JUNIO 2010               0.00%                     341.26%                               170.63%
# 107       JULIO 2010               0.00%                     343.94%                               171.97%
# 108      AGOSTO 2010               0.00%                     338.85%                               169.42%
# 109  SEPTIEMBRE 2010               0.00%                     330.48%                               165.24%
# 110     OCTUBRE 2010               0.00%                     330.76%                               165.38%
# 111   NOVIEMBRE 2010               0.00%                     324.64%                               162.32%
# 112   DICIEMBRE 2010               0.00%                     320.19%                               160.09%
# 113       ENERO 2011               0.00%                     314.90%                                  None
# 114     FEBRERO 2011               0.00%                     314.63%                                  None
# 115       MARZO 2011               0.00%                     306.21%                               153.11%
# 116       ABRIL 2011               0.00%                     301.72%                               150.86%
# 117        MAYO 2011               0.00%                     296.97%                                  None
# 118      AGOSTO 2011               0.00%                     276.89%                               138.45%
# 119  SEPTIEMBRE 2011               0.00%                     277.14%                               138.57%
# 120     OCTUBRE 2011               0.00%                     275.53%                               137.77%
# 121   NOVIEMBRE 2011               0.00%                     266.92%                               133.46%
# 122   DICIEMBRE 2011               0.00%                     261.92%                               130.96%
# 123       ENERO 2012               0.00%                     250.69%                                  None
# 124     FEBRERO 2012               0.00%                     249.57%                                  None
# 125       MARZO 2012               0.00%                     238.60%                               119.30%
# 126       ABRIL 2012               0.00%                     233.05%                               116.52%
# 127        MAYO 2012               0.00%                     227.08%                               113.54%
# 128       JUNIO 2012               0.00%                     233.02%                               116.51%
# 129       JULIO 2012               0.00%                     217.06%                               108.53%
# 130      AGOSTO 2012               0.00%                     211.39%                               105.69%
# 131  SEPTIEMBRE 2012               0.00%                     209.61%                               104.81%
# 132     OCTUBRE 2012               0.00%                     204.41%                               102.20%
# 133   NOVIEMBRE 2012               0.00%                     199.78%                                99.64%
# 134   DICIEMBRE 2012               0.00%                     193.60%                                96.80%
# 135       ENERO 2013               0.00%                     182.78%                                91.39%
# 136     FEBRERO 2013               0.00%                     182.78%                                91.39%
# 137       MARZO 2013               0.00%                     177.57%                                88.78%
# 138       ABRIL 2013               0.00%                     172.46%                                86.23%
# 139        MAYO 2013               0.00%                     163.11%                                81.55%
# 140       JUNIO 2013               0.00%                     158.30%                                79.15%
# 141       JULIO 2013               0.00%                     157.16%                                78.58%
# 142      AGOSTO 2013               0.00%                     152.52%                                76.26%
# 143  SEPTIEMBRE 2013               0.00%                     147.84%                                73.92%
# 144     OCTUBRE 2013               0.00%                     143.33%                                71.67%
# 145   NOVIEMBRE 2013               0.00%                     139.10%                                69.55%
# 146   DICIEMBRE 2013               0.00%                     134.70%                                67.35%
# 147       ENERO 2014               0.00%                     122.49%                                  None
# 148     FEBRERO 2014               0.00%                     126.82%                                  None
# 149       MARZO 2014               0.00%                     122.83%                                61.42%
# 150       ABRIL 2014               0.00%                     118.80%                                59.40%
# 151        MAYO 2014               0.00%                     111.10%                                55.55%
# 152       JUNIO 2014               0.00%                     107.57%                                53.79%
# 153       JULIO 2014               0.00%                     107.74%                                53.87%
# 154      AGOSTO 2014               0.00%                     104.28%                                52.14%
# 155  SEPTIEMBRE 2014               0.00%                      97.03%                                48.51%
# 156     OCTUBRE 2014               0.00%                      93.46%                                46.73%
# 157   NOVIEMBRE 2014               0.00%                      93.86%                                46.93%
# 158   DICIEMBRE 2014               0.00%                      90.25%                                45.12%
# 159       ENERO 2015               0.00%                      81.02%                                40.51%
# 160     FEBRERO 2015               0.00%                      84.07%                                42.03%
# 161       MARZO 2015               0.00%                      77.55%                                38.77%
# 162       ABRIL 2015               0.00%                      74.16%                                37.08%
# 163        MAYO 2015               0.00%                      74.28%                                37.14%
# 164       JUNIO 2015               0.00%                      68.39%                                34.19%
# 165       JULIO 2015               0.00%                      68.79%                                34.39%
# 166      AGOSTO 2015               0.00%                      66.04%                                33.02%
# 167  SEPTIEMBRE 2015               0.00%                      61.70%                                30.85%
# 168     OCTUBRE 2015               0.00%                      62.94%                                31.47%
# 169   NOVIEMBRE 2015               0.00%                      57.89%                                28.95%
# 170   DICIEMBRE 2015               0.00%                      55.13%                                27.56%
# 171       ENERO 2016               0.00%                      47.20%                                  None
# 172     FEBRERO 2016               0.00%                      47.20%                                  None
# 173       MARZO 2016               0.00%                      47.38%                                23.69%
# 174       ABRIL 2016               0.00%                      44.90%                                22.45%
# 175        MAYO 2016               0.00%                      41.31%                                21.15%
# 176       JUNIO 2016               0.00%                      42.30%                                21.15%
# 177       JULIO 2016               0.00%                      34.73%                                17.36%
# 178      AGOSTO 2016               0.00%                      32.15%                                16.07%
# 179  SEPTIEMBRE 2016               0.00%                      31.66%                                15.83%
# 180     OCTUBRE 2016               0.00%                      30.27%                                15.13%
# 181   NOVIEMBRE 2016               0.00%                      27.86%                                13.93%
# 182   DICIEMBRE 2016               0.00%                      25.73%                                12.86%
# 183       ENERO 2017               0.00%                      21.56%                                10.78%
# 184     FEBRERO 2017               0.00%                      21.36%                                10.68%
# 185       MARZO 2017               0.00%                      16.85%                                 8.43%
# 186       ABRIL 2017               0.00%                      14.62%                                 7.31%
# 187        MAYO 2017               0.00%                      14.70%                                 7.35%
# 188       JUNIO 2017               0.00%                      14.77%                                 7.39%
# 189       JULIO 2017               0.00%                      10.13%                                 5.06%
# 190      AGOSTO 2017               0.00%                       7.75%                                 3.88%
# 191  SEPTIEMBRE 2017               0.00%                       4.82%                                 2.41%
# 192     OCTUBRE 2017               0.00%                       5.49%                                 2.74%

# %%
# # Cargar el archivo CSV de datos reales
# csv_reales_path = '/content/drive/MyDrive/DEUDA_PREVISIONAL/datos_2017_reales.csv' # Asegúrate que esta ruta sea correcta

# try:
#     df_reales = pd.read_csv(csv_reales_path, sep=',') # Asegúrate que el separador sea el correcto
#     print(f"\nDataFrame de datos reales cargado desde '{csv_reales_path}':")
#     print(df_reales.head())
#     print(f"Columnas en df_reales: {df_reales.columns.tolist()}")

# except FileNotFoundError:
#     print(f"\nError: No se encontró el archivo CSV de datos reales en la ruta especificada: {csv_reales_path}")
#     df_reales = pd.DataFrame()
# except Exception as e:
#     print(f"\nOcurrió un error al cargar el archivo CSV de datos reales: {e}")
#     df_reales = pd.DataFrame()

# # Asegurarse de que df_final exista y no esté vacío antes de intentar la comparación
# if 'df_final' in locals() and not df_final.empty and not df_reales.empty:

#     rename_map = {
#         'reajuste_REAL_porcentaje': 'reajuste_porcentaje',
#         'interes_afiliado_REAL_porcentaje': 'interes_afiliado_porcentaje',
#         'recargo_beneficio_afiliado_REAL_porcentaje': 'recargo_beneficio_afiliado_porcentaje'
#     }
#     df_reales_renombrado = df_reales.rename(columns=rename_map)
#     print("\nDataFrame de datos reales renombrado para comparación:")
#     print(df_reales_renombrado.head())

#     if 'mes_año_columna' in df_final.columns and 'mes_año_columna' in df_reales_renombrado.columns:

#         # Normalizar 'mes_año_columna' para el merge (mayúsculas y sin espacios extra)
#         df_final['mes_año_columna_upper'] = df_final['mes_año_columna'].astype(str).str.upper().str.strip()
#         df_reales_renombrado['mes_año_columna_upper'] = df_reales_renombrado['mes_año_columna'].astype(str).str.upper().str.strip()

#         df_comparacion = pd.merge(
#             df_final,
#             df_reales_renombrado,
#             on='mes_año_columna_upper', # Usar la columna normalizada para el merge
#             suffixes=('_extraido', '_real'),
#             how='outer'
#         )

#         print("\nDataFrame de comparación (merge):")
#         print(df_comparacion.head().to_string())

#         def clean_and_convert_numeric(series_data):
#             if series_data is None:
#                 return pd.Series([pd.NA] * 1) # O la longitud que corresponda
#             # Convertir a string, luego limpiar y convertir a numérico
#             series_str = series_data.astype(str)
#             series_cleaned = series_str.str.replace('%', '', regex=False).str.replace(',', '.', regex=False)
#             return pd.to_numeric(series_cleaned, errors='coerce')


#         cols_to_compare = ['reajuste_porcentaje', 'interes_afiliado_porcentaje', 'recargo_beneficio_afiliado_porcentaje']
#         alertas = []

#         for col in cols_to_compare:
#             col_extraido = col + '_extraido'
#             col_real = col + '_real'

#             # Aplicar limpieza y conversión a las columnas del DataFrame de comparación
#             if col_extraido in df_comparacion.columns:
#                 df_comparacion[col_extraido + '_numeric'] = clean_and_convert_numeric(df_comparacion[col_extraido])
#             else:
#                  df_comparacion[col_extraido + '_numeric'] = pd.Series([pd.NA] * len(df_comparacion))

#             if col_real in df_comparacion.columns:
#                 df_comparacion[col_real + '_numeric'] = clean_and_convert_numeric(df_comparacion[col_real])
#             else:
#                 df_comparacion[col_real + '_numeric'] = pd.Series([pd.NA] * len(df_comparacion))


#             tolerancia = 1e-2

#             # Asegurarse que las columnas numéricas existen antes de operar
#             if (col_extraido + '_numeric' in df_comparacion.columns and
#                 col_real + '_numeric' in df_comparacion.columns):

#                 mask_ambos_existentes = df_comparacion[col_extraido + '_numeric'].notna() & df_comparacion[col_real + '_numeric'].notna()
#                 mask_diferentes = mask_ambos_existentes & (abs(df_comparacion[col_extraido + '_numeric'] - df_comparacion[col_real + '_numeric']) > tolerancia)

#                 for index, row in df_comparacion[mask_diferentes].iterrows():
#                     alerta = {
#                         'mes_año': row.get('mes_año_columna_upper', 'N/A'), # Usar .get para evitar KeyError
#                         'columna': col,
#                         'valor_extraido': row.get(col_extraido, 'N/A'),
#                         'valor_real': row.get(col_real, 'N/A'),
#                         'tipo_alerta': 'Diferencia significativa'
#                     }
#                     alertas.append(alerta)
#             else:
#                 print(f"Advertencia: Columnas numéricas para '{col}' no encontradas completamente en df_comparacion.")


#         # Meses/años extraídos pero no en los datos reales
#         # Usar mes_año_columna_extraido (de df_final) y mes_año_columna_real (de df_reales_renombrado)
#         # Estas columnas se crean por el merge si el on='mes_año_columna_upper' fue exitoso
#         # y las columnas originales eran 'mes_año_columna'
#         if 'mes_año_columna_extraido' in df_comparacion.columns and 'mes_año_columna_real' in df_comparacion.columns:
#             mask_solo_extraido = df_comparacion['mes_año_columna_real'].isna() & df_comparacion['mes_año_columna_extraido'].notna()
#             for index, row in df_comparacion[mask_solo_extraido].iterrows():
#                 alerta = {
#                     'mes_año': row.get('mes_año_columna_upper', 'N/A'),
#                     'columna': 'General',
#                     'valor_extraido': 'Presente',
#                     'valor_real': 'Ausente',
#                     'tipo_alerta': 'Mes/Año extraído, pero no en CSV real'
#                 }
#                 if not any(a['mes_año'] == alerta['mes_año'] and a['tipo_alerta'] == alerta['tipo_alerta'] for a in alertas):
#                     alertas.append(alerta)

#             mask_solo_real = df_comparacion['mes_año_columna_extraido'].isna() & df_comparacion['mes_año_columna_real'].notna()
#             for index, row in df_comparacion[mask_solo_real].iterrows():
#                 alerta = {
#                     'mes_año': row.get('mes_año_columna_upper', 'N/A'),
#                     'columna': 'General',
#                     'valor_extraido': 'Ausente',
#                     'valor_real': 'Presente',
#                     'tipo_alerta': 'Mes/Año en CSV real, pero no extraído'
#                 }
#                 if not any(a['mes_año'] == alerta['mes_año'] and a['tipo_alerta'] == alerta['tipo_alerta'] for a in alertas):
#                     alertas.append(alerta)
#         else:
#             print("Advertencia: Las columnas 'mes_año_columna_extraido' o 'mes_año_columna_real' no se encontraron después del merge. No se pueden generar alertas de solo_extraido/solo_real.")


#         print("\n--- ALERTA DE COMPARACIÓN ---")
#         if alertas:
#             for alerta in alertas:
#                 print(f"ALERTA: Mes/Año: {alerta['mes_año']}, Columna: {alerta['columna']}, Tipo: {alerta['tipo_alerta']}")
#                 if alerta['tipo_alerta'] == 'Diferencia significativa':
#                     print(f"  > Extraído: '{alerta['valor_extraido']}', Real: '{alerta['valor_real']}'")
#         else:
#             print("No se encontraron diferencias significativas ni meses/años faltantes en la comparación.")

#         if alertas:
#             df_alertas = pd.DataFrame(alertas)
#             print("\nDataFrame de Alertas:")
#             print(df_alertas.to_string())
#             excel_filename_final = f"datos_extraidos_comparados_alertas.xlsx"

#             try:
#                 with pd.ExcelWriter(excel_filename_final) as writer:
#                     if not df_final.empty:
#                         df_final.to_excel(writer, sheet_name='DatosExtraidos', index=False)
#                     if not df_comparacion.empty:
#                          df_comparacion.to_excel(writer, sheet_name='DataFrameComparacion', index=False)
#                     if not df_alertas.empty:
#                         df_alertas.to_excel(writer, sheet_name='AlertasComparacion', index=False)

#                 print(f"\nArchivos Excel guardados en '{excel_filename_final}'.")
#                 from google.colab import files
#                 files.download(excel_filename_final)
#                 print(f"Iniciando descarga de '{excel_filename_final}'...")
#             except Exception as e:
#                 print(f"Error al guardar el archivo Excel '{excel_filename_final}': {e}")
#         else:
#             if not df_final.empty:
#                 excel_filename_final_no_alertas = "datos_extraidos_final_sin_alertas_comp.xlsx"
#                 try:
#                     df_final.to_excel(excel_filename_final_no_alertas, index=False)
#                     print(f"\nDataFrame extraído (sin alertas de comparación) guardado como '{excel_filename_final_no_alertas}'.")
#                     from google.colab import files
#                     files.download(excel_filename_final_no_alertas)
#                     print(f"Iniciando descarga de '{excel_filename_final_no_alertas}'...")
#                 except Exception as e:
#                     print(f"Error al guardar el archivo Excel '{excel_filename_final_no_alertas}': {e}")
#     else:
#         print("\nLa columna 'mes_año_columna' no se encontró en uno o ambos DataFrames. No se puede realizar la comparación.")
# else:
#     print("\nDataFrame extraído (df_final) o DataFrame real (df_reales) no existe o está vacío. No se realizó la comparación.")
#     if 'df_final' in locals() and not df_final.empty:
#         excel_filename_solo_extraido = "datos_extraidos_final_solo.xlsx"
#         try:
#             df_final.to_excel(excel_filename_solo_extraido, index=False)
#             print(f"\nDataFrame extraído (sin comparación) guardado como '{excel_filename_solo_extraido}'.")
#             from google.colab import files
#             files.download(excel_filename_solo_extraido)
#             print(f"Iniciando descarga de '{excel_filename_solo_extraido}'...")
#         except Exception as e:
#             print(f"Error al guardar el archivo Excel '{excel_filename_solo_extraido}': {e}")

# %%
if 'df_final' in locals() and not df_final.empty:
    def clean_percentage(perc_str):
        if pd.isna(perc_str) or perc_str is None:
            return None
        try:
            return float(str(perc_str).replace('%', '').replace(',', '.'))
        except ValueError:
            # Intenta manejar casos como "658.76" sin el %
            try:
                return float(str(perc_str).replace(',', '.'))
            except ValueError:
                return None


    df_final['interes_afiliado_porcentaje_clean'] = df_final['interes_afiliado_porcentaje'].apply(clean_percentage)
    df_final['recargo_beneficio_afiliado_porcentaje_clean'] = df_final['recargo_beneficio_afiliado_porcentaje'].apply(clean_percentage)

    # Asegurar que las columnas _clean sean numéricas para .diff()
    df_final['interes_afiliado_porcentaje_clean'] = pd.to_numeric(df_final['interes_afiliado_porcentaje_clean'], errors='coerce')
    df_final['recargo_beneficio_afiliado_porcentaje_clean'] = pd.to_numeric(df_final['recargo_beneficio_afiliado_porcentaje_clean'], errors='coerce')


    df_final['variacion_interes'] = df_final['interes_afiliado_porcentaje_clean'].diff().abs()
    df_final['alerta_interes'] = (df_final['variacion_interes'] > 100) & (df_final['interes_afiliado_porcentaje_clean'].shift(1).notna())

    df_final['variacion_recargo'] = df_final['recargo_beneficio_afiliado_porcentaje_clean'].diff().abs()
    df_final['alerta_recargo'] = (df_final['variacion_recargo'] > 20) & (df_final['recargo_beneficio_afiliado_porcentaje_clean'].shift(1).notna())

    df_final['alerta_general_variacion'] = df_final['alerta_interes'] | df_final['alerta_recargo']

    print("\n--- DataFrame con Columnas de Alerta de Variación Interna ---")
    cols_to_show_alertas_internas = ['mes_año_columna',
                                     'interes_afiliado_porcentaje', 'interes_afiliado_porcentaje_clean', 'variacion_interes', 'alerta_interes',
                                     'recargo_beneficio_afiliado_porcentaje', 'recargo_beneficio_afiliado_porcentaje_clean', 'variacion_recargo', 'alerta_recargo',
                                     'alerta_general_variacion']
    # Filtrar para mostrar solo las columnas que existen en df_final
    cols_to_show_alertas_internas_existentes = [col for col in cols_to_show_alertas_internas if col in df_final.columns]
    print(df_final[cols_to_show_alertas_internas_existentes].to_string())


    if not df_final.empty:
        excel_filename_alertas_variacion = "datos_extraidos_final_CON_ALERTAS_VARIACION.xlsx"
        try:
            # Si la celda anterior (comparación) ya guardó un excel, podríamos querer añadir estas alertas como una nueva hoja
            # o sobreescribir/crear uno nuevo. Aquí se crea/sobrescribe.
            with pd.ExcelWriter(excel_filename_alertas_variacion) as writer:
                df_final.to_excel(writer, sheet_name='DatosConAlertasVariacion', index=False)
                # Si df_comparacion y df_alertas (de la celda anterior) existen y quieres incluirlos:
                if 'df_comparacion' in locals() and not df_comparacion.empty:
                    df_comparacion.to_excel(writer, sheet_name='ComparacionConReales', index=False)
                if 'df_alertas' in locals() and isinstance(df_alertas, pd.DataFrame) and not df_alertas.empty:
                    df_alertas.to_excel(writer, sheet_name='AlertasComparacionReales', index=False)

            print(f"\nDataFrame con alertas de variación guardado como '{excel_filename_alertas_variacion}'.")
            from google.colab import files
            files.download(excel_filename_alertas_variacion)
            print(f"Iniciando descarga de '{excel_filename_alertas_variacion}'...")
        except Exception as e:
            print(f"Error al guardar el archivo Excel '{excel_filename_alertas_variacion}': {e}")
    else:
        print("\nEl DataFrame final está vacío, no se guardará en Excel con alertas de variación.")
else:
    print("\nEl DataFrame 'df_final' no existe o está vacío. No se pueden generar alertas de variación interna.")
# Out:
# --- DataFrame con Columnas de Alerta de Variación Interna ---
#      mes_año_columna interes_afiliado_porcentaje  interes_afiliado_porcentaje_clean  variacion_interes  alerta_interes recargo_beneficio_afiliado_porcentaje  recargo_beneficio_afiliado_porcentaje_clean  variacion_recargo  alerta_recargo  alerta_general_variacion
# 0          MAYO 1997                    3293.80%                            3293.80                NaN           False                               658.76%                                       658.76                NaN           False                     False
# 1         JUNIO 1997                    3250.14%                            3250.14              43.66           False                               650.03%                                       650.03               8.73           False                     False
# 2         JULIO 1997                    3207.96%                            3207.96              42.18           False                               641.59%                                       641.59               8.44           False                     False
# 3        AGOSTO 1997                    3171.91%                            3171.91              36.05           False                               634.38%                                       634.38               7.21           False                     False
# 4    SEPTIEMBRE 1997                    3143.02%                            3143.02              28.89           False                               628.60%                                       628.60               5.78           False                     False
# 5       OCTUBRE 1997                    3110.70%                            3110.70              32.32           False                               622.14%                                       622.14               6.46           False                     False
# 6     NOVIEMBRE 1997                    3088.33%                            3088.33              22.37           False                               617.67%                                       617.67               4.47           False                     False
# 7     DICIEMBRE 1997                    3053.74%                            3053.74              34.59           False                               610.75%                                       610.75               6.92           False                     False
# 8         ENERO 1998                    3006.95%                            3006.95              46.79           False                               601.39%                                       601.39               9.36           False                     False
# 9       FEBRERO 1998                    2971.31%                            2971.31              35.64           False                               594.26%                                       594.26               7.13           False                     False
# 10        MARZO 1998                    2921.98%                            2921.98              49.33           False                               584.40%                                       584.40               9.86           False                     False
# 11        ABRIL 1998                    2861.70%                            2861.70              60.28           False                               572.34%                                       572.34              12.06           False                     False
# 12         MAYO 1998                    2821.42%                            2821.42              40.28           False                               564.28%                                       564.28               8.06           False                     False
# 13        JUNIO 1998                    2772.00%                            2772.00              49.42           False                               554.40%                                       554.40               9.88           False                     False
# 14        JULIO 1998                    2755.15%                            2755.15              16.85           False                               551.03%                                       551.03               3.37           False                     False
# 15       AGOSTO 1998                    2714.92%                            2714.92              40.23           False                               542.98%                                       542.98               8.05           False                     False
# 16   SEPTIEMBRE 1998                    2663.63%                            2663.63              51.29           False                               532.73%                                       532.73              10.25           False                     False
# 17      OCTUBRE 1998                    2615.84%                            2615.84              47.79           False                               523.17%                                       523.17               9.56           False                     False
# 18    NOVIEMBRE 1998                    2560.79%                            2560.79              55.05           False                               512.16%                                       512.16              11.01           False                     False
# 19    DICIEMBRE 1998                    2498.89%                            2498.89              61.90           False                               499.78%                                       499.78              12.38           False                     False
# 20        ENERO 1999                    2452.21%                            2452.21              46.68           False                               490.44%                                       490.44               9.34           False                     False
# 21      FEBRERO 1999                    2418.62%                            2418.62              33.59           False                               483.72%                                       483.72               6.72           False                     False
# 22        MARZO 1999                    2384.41%                            2384.41              34.21           False                               476.88%                                       476.88               6.84           False                     False
# 23        ABRIL 1999                    2360.35%                            2360.35              24.06           False                               472.07%                                       472.07               4.81           False                     False
# 24         MAYO 1999                    2340.97%                            2340.97              19.38           False                               468.19%                                       468.19               3.88           False                     False
# 25        JUNIO 1999                    2289.64%                            2289.64              51.33           False                               457.93%                                       457.93              10.26           False                     False
# 26        JULIO 1999                    2254.88%                            2254.88              34.76           False                               450.98%                                       450.98               6.95           False                     False
# 27       AGOSTO 1999                    2209.98%                            2209.98              44.90           False                               442.00%                                       442.00               8.98           False                     False
# 28   SEPTIEMBRE 1999                    2201.06%                            2201.06               8.92           False                               440.21%                                       440.21               1.79           False                     False
# 29      OCTUBRE 1999                    2162.56%                            2162.56              38.50           False                               432.51%                                       432.51               7.70           False                     False
# 30    NOVIEMBRE 1999                    2083.69%                            2083.69              78.87           False                               416.74%                                       416.74              15.77           False                     False
# 31    DICIEMBRE 1999                    2048.86%                            2048.86              34.83           False                               409.77%                                       409.77               6.97           False                     False
# 32        JUNIO 2000                    1901.46%                            1901.46             147.40            True                               380.29%                                       380.29              29.48            True                      True
# 33        JULIO 2000                    1877.29%                            1877.29              24.17           False                               375.46%                                       375.46               4.83           False                     False
# 34    NOVIEMBRE 2000                    1761.25%                            1761.25             116.04            True                               352.25%                                       352.25              23.21            True                      True
# 35    DICIEMBRE 2000                    1730.59%                            1730.59              30.66           False                               346.12%                                       346.12               6.13           False                     False
# 36       AGOSTO 2001                    1527.22%                            1527.22             203.37            True                               305.44%                                       305.44              40.68            True                      True
# 37   SEPTIEMBRE 2001                    1517.12%                            1517.12              10.10           False                               303.42%                                       303.42               2.02           False                     False
# 38    DICIEMBRE 2002                    1336.98%                            1336.98             180.14            True                               267.40%                                       267.40              36.02            True                      True
# 39      OCTUBRE 2003                    1206.58%                            1206.58             130.40            True                               241.32%                                       241.32              26.08            True                      True
# 40    NOVIEMBRE 2003                    1211.45%                            1211.45               4.87           False                               242.29%                                       242.29               0.97           False                     False
# 41      TIEMBRE 2004                    1069.53%                            1069.53             141.92            True                                  None                                          NaN                NaN           False                      True
# 42        MARZO 2004                    1131.33%                            1131.33              61.80           False                               226.27%                                       226.27                NaN           False                     False
# 43        ABRIL 2004                    1142.69%                            1142.69              11.36           False                               228.54%                                       228.54               2.27           False                     False
# 44         MAYO 2004                    1127.55%                            1127.55              15.14           False                               225.51%                                       225.51               3.03           False                     False
# 45        JUNIO 2004                    1080.49%                            1080.49              47.06           False                               216.10%                                       216.10               9.41           False                     False
# 46       AGOSTO 2004                    1091.73%                            1091.73              11.24           False                               218.35%                                       218.35               2.25           False                     False
# 47   SEPTIEMBRE 2004                    1080.02%                            1080.02              11.71           False                               216.00%                                       216.00               2.35           False                     False
# 48      OCTUBRE 2004                    1066.56%                            1066.56              13.46           False                                  None                                          NaN                NaN           False                     False
# 49    NOVIEMBRE 2004                    1063.59%                            1063.59               2.97           False                                  None                                          NaN                NaN           False                     False
# 50    DICIEMBRE 2004                    1046.39%                            1046.39              17.20           False                               209.28%                                       209.28                NaN           False                     False
# 51        ENERO 2005                    1035.28%                            1035.28              11.11           False                               207.06%                                       207.06               2.22           False                     False
# 52       AGOSTO 2005                     960.37%                             960.37              74.91           False                               192.07%                                       192.07              14.99           False                     False
# 53   SEPTIEMBRE 2005                     947.66%                             947.66              12.71           False                               189.53%                                       189.53               2.54           False                     False
# 54      OCTUBRE 2005                     920.28%                             920.28              27.38           False                               184.06%                                       184.06               5.47           False                     False
# 55        ENERO 2006                     906.25%                             906.25              14.03           False                               181.25%                                       181.25               2.81           False                     False
# 56      FEBRERO 2006                     894.94%                             894.94              11.31           False                               178.99%                                       178.99               2.26           False                     False
# 57        MARZO 2006                     891.90%                             891.90               3.04           False                               445.95%                                       445.95             266.96            True                      True
# 58        ABRIL 2006                     879.23%                             879.23              12.67           False                               439.62%                                       439.62               6.33           False                     False
# 59         MAYO 2006                     849.97%                             849.97              29.26           False                               424.99%                                       424.99              14.63           False                     False
# 60        JUNIO 2006                     846.57%                             846.57               3.40           False                               423.28%                                       423.28               1.71           False                     False
# 61        JULIO 2006                     826.81%                             826.81              19.76           False                               413.41%                                       413.41               9.87           False                     False
# 62       AGOSTO 2006                     807.70%                             807.70              19.11           False                               403.85%                                       403.85               9.56           False                     False
# 63   SEPTIEMBRE 2006                     808.28%                             808.28               0.58           False                               404.14%                                       404.14               0.29           False                     False
# 64      OCTUBRE 2006                     808.86%                             808.86               0.58           False                               404.43%                                       404.43               0.29           False                     False
# 65    NOVIEMBRE 2006                     789.79%                             789.79              19.07           False                               394.90%                                       394.90               9.53           False                     False
# 66    DICIEMBRE 2006                     778.22%                             778.22              11.57           False                               389.11%                                       389.11               5.79           False                     False
# 67        ENERO 2007                     753.40%                             753.40              24.82           False                               376.70%                                       376.70              12.41           False                     False
# 68      FEBRERO 2007                        None                                NaN                NaN           False                                  None                                          NaN                NaN           False                     False
# 69        MARZO 2007                     741.46%                             741.46                NaN           False                               370.73%                                       370.73                NaN           False                     False
# 70        ABRIL 2007                     729.91%                             729.91              11.55           False                               364.96%                                       364.96               5.77           False                     False
# 71         MAYO 2007                     702.83%                             702.83              27.08           False                               351.41%                                       351.41              13.55           False                     False
# 72        JUNIO 2007                     690.79%                             690.79              12.04           False                               345.40%                                       345.40               6.01           False                     False
# 73        JULIO 2007                     680.33%                             680.33              10.46           False                               340.16%                                       340.16               5.24           False                     False
# 74       AGOSTO 2007                     663.53%                             663.53              16.80           False                               331.76%                                       331.76               8.40           False                     False
# 75   SEPTIEMBRE 2007                     653.08%                             653.08              10.45           False                               326.54%                                       326.54               5.22           False                     False
# 76      OCTUBRE 2007                     638.77%                             638.77              14.31           False                               319.39%                                       319.39               7.15           False                     False
# 77    NOVIEMBRE 2007                     632.32%                             632.32               6.45           False                               316.16%                                       316.16               3.23           False                     False
# 78    DICIEMBRE 2007                     617.90%                             617.90              14.42           False                               308.95%                                       308.95               7.21           False                     False
# 79        ENERO 2008                     597.86%                             597.86              20.04           False                                  None                                          NaN                NaN           False                     False
# 80      FEBRERO 2008                     597.86%                             597.86               0.00           False                                  None                                          NaN                NaN           False                     False
# 81        MARZO 2008                     588.60%                             588.60               9.26           False                               294.30%                                       294.30                NaN           False                     False
# 82        ABRIL 2008                     578.92%                             578.92               9.68           False                               289.46%                                       289.46               4.84           False                     False
# 83         MAYO 2008                     570.42%                             570.42               8.50           False                               285.21%                                       285.21               4.25           False                     False
# 84        JUNIO 2008                     561.16%                             561.16               9.26           False                               280.58%                                       280.58               4.63           False                     False
# 85        JULIO 2008                     551.28%                             551.28               9.88           False                               275.64%                                       275.64               4.94           False                     False
# 86       AGOSTO 2008                     542.46%                             542.46               8.82           False                               271.23%                                       271.23               4.41           False                     False
# 87   SEPTIEMBRE 2008                     528.98%                             528.98              13.48           False                               264.49%                                       264.49               6.74           False                     False
# 88      OCTUBRE 2008                     529.38%                             529.38               0.40           False                               264.69%                                       264.69               0.20           False                     False
# 89    NOVIEMBRE 2008                     515.18%                             515.18              14.20           False                               257.59%                                       257.59               7.10           False                     False
# 90    DICIEMBRE 2008                     504.98%                             504.98              10.20           False                               252.49%                                       252.49               5.10           False                     False
# 91    NOVILMBRE 2009                     417.42%                             417.42              87.56           False                               208.71%                                       208.71              43.78            True                      True
# 92        ENERO 2009                     475.09%                             475.09              57.67           False                               237.55%                                       237.55              28.84            True                      True
# 93        MARZO 2009                     465.22%                             465.22               9.87           False                                  None                                          NaN                NaN           False                     False
# 94        ABRIL 2009                     465.87%                             465.87               0.65           False                                  None                                          NaN                NaN           False                     False
# 95         MAYO 2009                     454.92%                             454.92              10.95           False                               227.46%                                       227.46                NaN           False                     False
# 96        JULIO 2009                     439.92%                             439.92              15.00           False                               219.96%                                       219.96               7.50           False                     False
# 97       AGOSTO 2009                     432.41%                             432.41               7.51           False                               216.20%                                       216.20               3.76           False                     False
# 98   SEPTIEMBRE 2009                     419.44%                             419.44              12.97           False                               209.72%                                       209.72               6.48           False                     False
# 99      OCTUBRE 2009                     415.27%                             415.27               4.17           False                               207.63%                                       207.63               2.09           False                     False
# 100   DICIEMBRE 2009                     407.87%                             407.87               7.40           False                               203.93%                                       203.93               3.70           False                     False
# 101       ENERO 2010                     390.82%                             390.82              17.05           False                                  None                                          NaN                NaN           False                     False
# 102     FEBRERO 2010                     382.87%                             382.87               7.95           False                                  None                                          NaN                NaN           False                     False
# 103       MARZO 2010                     378.24%                             378.24               4.63           False                               189.12%                                       189.12                NaN           False                     False
# 104       ABRIL 2010                     368.95%                             368.95               9.29           False                               184.47%                                       184.47               4.65           False                     False
# 105        MAYO 2010                     340.98%                             340.98              27.97           False                               170.49%                                       170.49              13.98           False                     False
# 106       JUNIO 2010                     341.26%                             341.26               0.28           False                               170.63%                                       170.63               0.14           False                     False
# 107       JULIO 2010                     343.94%                             343.94               2.68           False                               171.97%                                       171.97               1.34           False                     False
# 108      AGOSTO 2010                     338.85%                             338.85               5.09           False                               169.42%                                       169.42               2.55           False                     False
# 109  SEPTIEMBRE 2010                     330.48%                             330.48               8.37           False                               165.24%                                       165.24               4.18           False                     False
# 110     OCTUBRE 2010                     330.76%                             330.76               0.28           False                               165.38%                                       165.38               0.14           False                     False
# 111   NOVIEMBRE 2010                     324.64%                             324.64               6.12           False                               162.32%                                       162.32               3.06           False                     False
# 112   DICIEMBRE 2010                     320.19%                             320.19               4.45           False                               160.09%                                       160.09               2.23           False                     False
# 113       ENERO 2011                     314.90%                             314.90               5.29           False                                  None                                          NaN                NaN           False                     False
# 114     FEBRERO 2011                     314.63%                             314.63               0.27           False                                  None                                          NaN                NaN           False                     False
# 115       MARZO 2011                     306.21%                             306.21               8.42           False                               153.11%                                       153.11                NaN           False                     False
# 116       ABRIL 2011                     301.72%                             301.72               4.49           False                               150.86%                                       150.86               2.25           False                     False
# 117        MAYO 2011                     296.97%                             296.97               4.75           False                                  None                                          NaN                NaN           False                     False
# 118      AGOSTO 2011                     276.89%                             276.89              20.08           False                               138.45%                                       138.45                NaN           False                     False
# 119  SEPTIEMBRE 2011                     277.14%                             277.14               0.25           False                               138.57%                                       138.57               0.12           False                     False
# 120     OCTUBRE 2011                     275.53%                             275.53               1.61           False                               137.77%                                       137.77               0.80           False                     False
# 121   NOVIEMBRE 2011                     266.92%                             266.92               8.61           False                               133.46%                                       133.46               4.31           False                     False
# 122   DICIEMBRE 2011                     261.92%                             261.92               5.00           False                               130.96%                                       130.96               2.50           False                     False
# 123       ENERO 2012                     250.69%                             250.69              11.23           False                                  None                                          NaN                NaN           False                     False
# 124     FEBRERO 2012                     249.57%                             249.57               1.12           False                                  None                                          NaN                NaN           False                     False
# 125       MARZO 2012                     238.60%                             238.60              10.97           False                               119.30%                                       119.30                NaN           False                     False
# 126       ABRIL 2012                     233.05%                             233.05               5.55           False                               116.52%                                       116.52               2.78           False                     False
# 127        MAYO 2012                     227.08%                             227.08               5.97           False                               113.54%                                       113.54               2.98           False                     False
# 128       JUNIO 2012                     233.02%                             233.02               5.94           False                               116.51%                                       116.51               2.97           False                     False
# 129       JULIO 2012                     217.06%                             217.06              15.96           False                               108.53%                                       108.53               7.98           False                     False
# 130      AGOSTO 2012                     211.39%                             211.39               5.67           False                               105.69%                                       105.69               2.84           False                     False
# 131  SEPTIEMBRE 2012                     209.61%                             209.61               1.78           False                               104.81%                                       104.81               0.88           False                     False
# 132     OCTUBRE 2012                     204.41%                             204.41               5.20           False                               102.20%                                       102.20               2.61           False                     False
# 133   NOVIEMBRE 2012                     199.78%                             199.78               4.63           False                                99.64%                                        99.64               2.56           False                     False
# 134   DICIEMBRE 2012                     193.60%                             193.60               6.18           False                                96.80%                                        96.80               2.84           False                     False
# 135       ENERO 2013                     182.78%                             182.78              10.82           False                                91.39%                                        91.39               5.41           False                     False
# 136     FEBRERO 2013                     182.78%                             182.78               0.00           False                                91.39%                                        91.39               0.00           False                     False
# 137       MARZO 2013                     177.57%                             177.57               5.21           False                                88.78%                                        88.78               2.61           False                     False
# 138       ABRIL 2013                     172.46%                             172.46               5.11           False                                86.23%                                        86.23               2.55           False                     False
# 139        MAYO 2013                     163.11%                             163.11               9.35           False                                81.55%                                        81.55               4.68           False                     False
# 140       JUNIO 2013                     158.30%                             158.30               4.81           False                                79.15%                                        79.15               2.40           False                     False
# 141       JULIO 2013                     157.16%                             157.16               1.14           False                                78.58%                                        78.58               0.57           False                     False
# 142      AGOSTO 2013                     152.52%                             152.52               4.64           False                                76.26%                                        76.26               2.32           False                     False
# 143  SEPTIEMBRE 2013                     147.84%                             147.84               4.68           False                                73.92%                                        73.92               2.34           False                     False
# 144     OCTUBRE 2013                     143.33%                             143.33               4.51           False                                71.67%                                        71.67               2.25           False                     False
# 145   NOVIEMBRE 2013                     139.10%                             139.10               4.23           False                                69.55%                                        69.55               2.12           False                     False
# 146   DICIEMBRE 2013                     134.70%                             134.70               4.40           False                                67.35%                                        67.35               2.20           False                     False
# 147       ENERO 2014                     122.49%                             122.49              12.21           False                                  None                                          NaN                NaN           False                     False
# 148     FEBRERO 2014                     126.82%                             126.82               4.33           False                                  None                                          NaN                NaN           False                     False
# 149       MARZO 2014                     122.83%                             122.83               3.99           False                                61.42%                                        61.42                NaN           False                     False
# 150       ABRIL 2014                     118.80%                             118.80               4.03           False                                59.40%                                        59.40               2.02           False                     False
# 151        MAYO 2014                     111.10%                             111.10               7.70           False                                55.55%                                        55.55               3.85           False                     False
# 152       JUNIO 2014                     107.57%                             107.57               3.53           False                                53.79%                                        53.79               1.76           False                     False
# 153       JULIO 2014                     107.74%                             107.74               0.17           False                                53.87%                                        53.87               0.08           False                     False
# 154      AGOSTO 2014                     104.28%                             104.28               3.46           False                                52.14%                                        52.14               1.73           False                     False
# 155  SEPTIEMBRE 2014                      97.03%                              97.03               7.25           False                                48.51%                                        48.51               3.63           False                     False
# 156     OCTUBRE 2014                      93.46%                              93.46               3.57           False                                46.73%                                        46.73               1.78           False                     False
# 157   NOVIEMBRE 2014                      93.86%                              93.86               0.40           False                                46.93%                                        46.93               0.20           False                     False
# 158   DICIEMBRE 2014                      90.25%                              90.25               3.61           False                                45.12%                                        45.12               1.81           False                     False
# 159       ENERO 2015                      81.02%                              81.02               9.23           False                                40.51%                                        40.51               4.61           False                     False
# 160     FEBRERO 2015                      84.07%                              84.07               3.05           False                                42.03%                                        42.03               1.52           False                     False
# 161       MARZO 2015                      77.55%                              77.55               6.52           False                                38.77%                                        38.77               3.26           False                     False
# 162       ABRIL 2015                      74.16%                              74.16               3.39           False                                37.08%                                        37.08               1.69           False                     False
# 163        MAYO 2015                      74.28%                              74.28               0.12           False                                37.14%                                        37.14               0.06           False                     False
# 164       JUNIO 2015                      68.39%                              68.39               5.89           False                                34.19%                                        34.19               2.95           False                     False
# 165       JULIO 2015                      68.79%                              68.79               0.40           False                                34.39%                                        34.39               0.20           False                     False
# 166      AGOSTO 2015                      66.04%                              66.04               2.75           False                                33.02%                                        33.02               1.37           False                     False
# 167  SEPTIEMBRE 2015                      61.70%                              61.70               4.34           False                                30.85%                                        30.85               2.17           False                     False
# 168     OCTUBRE 2015                      62.94%                              62.94               1.24           False                                31.47%                                        31.47               0.62           False                     False
# 169   NOVIEMBRE 2015                      57.89%                              57.89               5.05           False                                28.95%                                        28.95               2.52           False                     False
# 170   DICIEMBRE 2015                      55.13%                              55.13               2.76           False                                27.56%                                        27.56               1.39           False                     False
# 171       ENERO 2016                      47.20%                              47.20               7.93           False                                  None                                          NaN                NaN           False                     False
# 172     FEBRERO 2016                      47.20%                              47.20               0.00           False                                  None                                          NaN                NaN           False                     False
# 173       MARZO 2016                      47.38%                              47.38               0.18           False                                23.69%                                        23.69                NaN           False                     False
# 174       ABRIL 2016                      44.90%                              44.90               2.48           False                                22.45%                                        22.45               1.24           False                     False
# 175        MAYO 2016                      41.31%                              41.31               3.59           False                                21.15%                                        21.15               1.30           False                     False
# 176       JUNIO 2016                      42.30%                              42.30               0.99           False                                21.15%                                        21.15               0.00           False                     False
# 177       JULIO 2016                      34.73%                              34.73               7.57           False                                17.36%                                        17.36               3.79           False                     False
# 178      AGOSTO 2016                      32.15%                              32.15               2.58           False                                16.07%                                        16.07               1.29           False                     False
# 179  SEPTIEMBRE 2016                      31.66%                              31.66               0.49           False                                15.83%                                        15.83               0.24           False                     False
# 180     OCTUBRE 2016                      30.27%                              30.27               1.39           False                                15.13%                                        15.13               0.70           False                     False
# 181   NOVIEMBRE 2016                      27.86%                              27.86               2.41           False                                13.93%                                        13.93               1.20           False                     False
# 182   DICIEMBRE 2016                      25.73%                              25.73               2.13           False                                12.86%                                        12.86               1.07           False                     False
# 183       ENERO 2017                      21.56%                              21.56               4.17           False                                10.78%                                        10.78               2.08           False                     False
# 184     FEBRERO 2017                      21.36%                              21.36               0.20           False                                10.68%                                        10.68               0.10           False                     False
# 185       MARZO 2017                      16.85%                              16.85               4.51           False                                 8.43%                                         8.43               2.25           False                     False
# 186       ABRIL 2017                      14.62%                              14.62               2.23           False                                 7.31%                                         7.31               1.12           False                     False
# 187        MAYO 2017                      14.70%                              14.70               0.08           False                                 7.35%                                         7.35               0.04           False                     False
# 188       JUNIO 2017                      14.77%                              14.77               0.07           False                                 7.39%                                         7.39               0.04           False                     False
# 189       JULIO 2017                      10.13%                              10.13               4.64           False                                 5.06%                                         5.06               2.33           False                     False
# 190      AGOSTO 2017                       7.75%                               7.75               2.38           False                                 3.88%                                         3.88               1.18           False                     False
# 191  SEPTIEMBRE 2017                       4.82%                               4.82               2.93           False                                 2.41%                                         2.41               1.47           False                     False
# 192     OCTUBRE 2017                       5.49%                               5.49               0.67           False                                 2.74%                                         2.74               0.33           False                     False
#
# DataFrame con alertas de variación guardado como 'datos_extraidos_final_CON_ALERTAS_VARIACION.xlsx'.
# Iniciando descarga de 'datos_extraidos_final_CON_ALERTAS_VARIACION.xlsx'...

# %%
# # Esta celda asume que la Celda 5 se ha ejecutado
# # y que la variable 'df_final' existe y es un DataFrame de Pandas.

# # Guardar a Excel (COMENTADO)
# if not df_final.empty:
#     excel_filename_final = "datos_extraidos_segmentados_final.xlsx"
#     df_final.to_excel(excel_filename_final, index=False)
#     print(f"\nDataFrame segmentado guardado como '{excel_filename_final}'.")

#     from google.colab import files # COMENTADO
#     files.download(excel_filename_final) # COMENTADO
# else:
#     print("\nEl DataFrame final está vacío, no se guardará en Excel.")
